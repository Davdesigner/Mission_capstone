# %% [markdown]
# <a href="https://colab.research.google.com/github/Davdesigner/Mission_capstone/blob/main/AminoRice_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AminoRice: Rice Quality Assessment Using Computer Vision
# ##Project overview
# AminoRice is an AI-powered mobile-integrated application designed to automatically assess rice grain quality using computer vision and deep learning techniques. The system analyzes uploaded images of rice samples and predicts key quality indicators such as grain integrity, defects, and overall grade.
#
# The core of AminoRice is a Convolutional Neural Network (CNN) trained on labeled rice grain datasets. The model processes image inputs, extracts visual features, and generates quality predictions that assist farmers, traders, and consumers in making data-driven decisions.

# %% [markdown]
# ### Download the images from cloud

# %%
# !apt-get install aria2 -y

# %%
# !aria2c -x 16 -s 16 -j 8 \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-001.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-002.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-003.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-004.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-005.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-006.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-007.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-008.zip

# %%
# !ls -lh
# Out:
# total 4.0G
# drwx------ 5 root root 4.0K Mar  6 09:02 drive
# -rw-r--r-- 1 root root 2.0G Mar  6 09:24 images-20251223T085919Z-3-001.zip
# -rw-r--r-- 1 root root 2.0G Mar  6 09:30 images-20251223T085919Z-3-002.zip
# drwxr-xr-x 1 root root 4.0K Jan 16 14:24 sample_data

# %%
# !aria2c -c -x 4 -s 4 -j 3 \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-002.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-003.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-004.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-005.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-006.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-007.zip \
https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-008.zip

# %%
urls = [
"https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-003.zip",
"https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-004.zip",
"https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-005.zip",
"https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-006.zip",
"https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-007.zip",
"https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-008.zip"
]

for url in urls:
    # !wget -c $url
# Out:
# --2026-03-06 09:31:33--  https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-003.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.130.207, 74.125.68.207, 74.125.24.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.130.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2145715591 (2.0G) [application/zip]
# Saving to: ‘images-20251223T085919Z-3-003.zip’
#
# images-20251223T085 100%[===================>]   2.00G  21.2MB/s    in 97s
#
# 2026-03-06 09:33:10 (21.2 MB/s) - ‘images-20251223T085919Z-3-003.zip’ saved [2145715591/2145715591]
#
# --2026-03-06 09:33:10--  https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-004.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.170.207, 142.251.10.207, 142.251.12.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.170.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2147273577 (2.0G) [application/zip]
# Saving to: ‘images-20251223T085919Z-3-004.zip’
#
# images-20251223T085 100%[===================>]   2.00G  21.3MB/s    in 96s
#
# 2026-03-06 09:34:46 (21.3 MB/s) - ‘images-20251223T085919Z-3-004.zip’ saved [2147273577/2147273577]
#
# --2026-03-06 09:34:47--  https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-005.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.194.207, 142.250.4.207, 64.233.170.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.194.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2147440954 (2.0G) [application/zip]
# Saving to: ‘images-20251223T085919Z-3-005.zip’
#
# images-20251223T085 100%[===================>]   2.00G  22.7MB/s    in 95s
#
# 2026-03-06 09:36:22 (21.5 MB/s) - ‘images-20251223T085919Z-3-005.zip’ saved [2147440954/2147440954]
#
# --2026-03-06 09:36:22--  https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-006.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.194.207, 142.250.4.207, 172.253.144.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.194.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2146108103 (2.0G) [application/zip]
# Saving to: ‘images-20251223T085919Z-3-006.zip’
#
# images-20251223T085 100%[===================>]   2.00G  17.4MB/s    in 98s
#
# 2026-03-06 09:38:01 (20.9 MB/s) - ‘images-20251223T085919Z-3-006.zip’ saved [2146108103/2146108103]
#
# --2026-03-06 09:38:01--  https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-007.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.194.207, 142.250.4.207, 64.233.170.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.194.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2140624067 (2.0G) [application/zip]
# Saving to: ‘images-20251223T085919Z-3-007.zip’
#
# images-20251223T085 100%[===================>]   1.99G  23.2MB/s    in 98s
#
# 2026-03-06 09:39:40 (20.7 MB/s) - ‘images-20251223T085919Z-3-007.zip’ saved [2140624067/2140624067]
#
# --2026-03-06 09:39:40--  https://storage.googleapis.com/unido-afririce/images-20251223T085919Z-3-008.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.12.207, 172.253.118.207, 74.125.200.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.12.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1380963272 (1.3G) [application/zip]
# Saving to: ‘images-20251223T085919Z-3-008.zip’
#
# images-20251223T085 100%[===================>]   1.29G  21.5MB/s    in 63s
#
# 2026-03-06 09:40:43 (20.9 MB/s) - ‘images-20251223T085919Z-3-008.zip’ saved [1380963272/1380963272]

# %%
# !mkdir -p /content/drive/MyDrive/rice_dataset
# !mv *.zip /content/drive/MyDrive/rice_dataset/
# %cd /content/drive/MyDrive/rice_dataset
# !for f in *.zip; do unzip "$f"; done
# Out:
# /content/drive/MyDrive/rice_dataset
# Archive:  images-20251223T085919Z-3-001.zip
#   inflating: images/ID_674BFC.png
#   inflating: images/ID_33EBD5.png
#   inflating: images/ID_8B0DC6.png
#   inflating: images/ID_BCC0D4.png
#   inflating: images/ID_A50ABB.png
#   inflating: images/ID_0E5566.png
#   inflating: images/ID_4F8765.png
#   inflating: images/ID_861DC9.png
#   inflating: images/ID_D10EC7.png
#   inflating: images/ID_3E313B.png
#   inflating: images/ID_86109D.png
#   inflating: images/ID_053116.png
#   inflating: images/ID_C73DFE.png
#   inflating: images/ID_EE8374.png
#   inflating: images/ID_82965D.png
#   inflating: images/ID_5E1B18.png
#   inflating: images/ID_E48E13.png
#   inflating: images/ID_8EDD72.png
#   inflating: images/ID_C70DAF.png
#   inflating: images/ID_BB7946.png
#   inflating: images/ID_9CB67F.png
#   inflating: images/ID_3D779C.png
#   inflating: images/ID_F9BE31.png
#   inflating: images/ID_FE5151.png
#   inflating: images/ID_E077E1.png
#   inflating: images/ID_DC960C.png
#   inflating: images/ID_01E956.png
#   inflating: images/ID_4C22BD.png
#   inflating: images/ID_50905D.png
#   inflating: images/ID_3546AB.png
#   inflating: images/ID_4671AE.png
#   inflating: images/ID_17FAFE.png
#   inflating: images/ID_A0872C.png
#   inflating: images/ID_996009.png
#   inflating: images/ID_28E209.png
#   inflating: images/ID_93FB9D.png
#   inflating: images/ID_7BB060.png
#   inflating: images/ID_7940AB.png
#   inflating: images/ID_FD5C90.png
#   inflating: images/ID_F29B38.png
#   inflating: images/ID_F3F1B7.png
#   inflating: images/ID_4476B9.png
#   inflating: images/ID_F09696.png
#   inflating: images/ID_1EE3DF.png
#   inflating: images/ID_D282EF.png
#   inflating: images/ID_5CAF41.png
#   inflating: images/ID_2A50E9.png
#   inflating: images/ID_76CF99.png
#   inflating: images/ID_F93882.png
#   inflating: images/ID_DFD746.png
#   inflating: images/ID_535AB7.png
#   inflating: images/ID_C0A271.png
#   inflating: images/ID_0E9FA1.png
#   inflating: images/ID_286674.png
#   inflating: images/ID_A0833C.png
#   inflating: images/ID_459A4D.png
#   inflating: images/ID_DC87C1.png
#   inflating: images/ID_2812E5.png
#   inflating: images/ID_082942.png
#   inflating: images/ID_407901.png
#   inflating: images/ID_944BDD.png
#   inflating: images/ID_7C82FA.png
#   inflating: images/ID_6F3E29.png
#   inflating: images/ID_2DF452.png
#   inflating: images/ID_A51FB9.png
#   inflating: images/ID_84438B.png
#   inflating: images/ID_018B59.png
#   inflating: images/ID_71F627.png
#   inflating: images/ID_1CECC7.png
#   inflating: images/ID_D94E18.png
#   inflating: images/ID_702229.png
#   inflating: images/ID_E702E5.png
#   inflating: images/ID_F91E24.png
#   inflating: images/ID_7810CC.png
#   inflating: images/ID_242C10.png
#   inflating: images/ID_AB1A4D.png
#   inflating: images/ID_D75917.png
#   inflating: images/ID_995665.png
#   inflating: images/ID_BB04AF.png
#   inflating: images/ID_DA11E8.png
#   inflating: images/ID_FB60D4.png
#   inflating: images/ID_C1E39D.png
#   inflating: images/ID_6C8DBA.png
#   inflating: images/ID_17326D.png
#   inflating: images/ID_F4573F.png
#   inflating: images/ID_68A83E.png
#   inflating: images/ID_26588E.png
#   inflating: images/ID_DC4C44.png
#   inflating: images/ID_B51A15.png
#   inflating: images/ID_B495CE.png
#   inflating: images/ID_0CE2FF.png
#   inflating: images/ID_E32510.png
#   inflating: images/ID_884CE4.png
#   inflating: images/ID_8E2CFD.png
#   inflating: images/ID_7EB3C8.png
#   inflating: images/ID_CD758E.png
#   inflating: images/ID_C85037.png
#   inflating: images/ID_E00406.png
#   inflating: images/ID_193002.png
#   inflating: images/ID_81E5F8.png
#   inflating: images/ID_3BF55B.png
#   inflating: images/ID_E6D854.png
#   inflating: images/ID_A284DF.png
#   inflating: images/ID_39E497.png
#   inflating: images/ID_E1D5BE.png
#   inflating: images/ID_905056.png
#   inflating: images/ID_2C8910.png
#   inflating: images/ID_A9EB81.png
#   inflating: images/ID_5EAC43.png
#   inflating: images/ID_838E8A.png
#   inflating: images/ID_81DC9B.png
#   inflating: images/ID_E53A0A.png
#   inflating: images/ID_A9078E.png
#   inflating: images/ID_E034FB.png
#   inflating: images/ID_EB86D5.png
#   inflating: images/ID_B3BA8F.png
#   inflating: images/ID_4122CB.png
#   inflating: images/ID_6C14DA.png
#   inflating: images/ID_310CE6.png
#   inflating: images/ID_7BCCFD.png
#   inflating: images/ID_D38901.png
#   inflating: images/ID_1C65CE.png
#   inflating: images/ID_3948EA.png
#   inflating: images/ID_2DE5D1.png
#   inflating: images/ID_25DF35.png
#   inflating: images/ID_1D7231.png
#   inflating: images/ID_3A029F.png
#   inflating: images/ID_C4851E.png
#   inflating: images/ID_285AB9.png
#   inflating: images/ID_4E4E53.png
#   inflating: images/ID_999653.png
#   inflating: images/ID_3F67FD.png
#   inflating: images/ID_43CCA4.png
#   inflating: images/ID_271551.png
#   inflating: images/ID_B24D51.png
#   inflating: images/ID_3210DD.png
#   inflating: images/ID_A01610.png
#   inflating: images/ID_F7CADE.png
#   inflating: images/ID_2BA869.png
#   inflating: images/ID_C8BA76.png
#   inflating: images/ID_A4D2F0.png
#   inflating: images/ID_68D13C.png
#   inflating: images/ID_6A61D4.png
#   inflating: images/ID_33CEB0.png
#   inflating: images/ID_7E7E69.png
#   inflating: images/ID_144A3F.png
#   inflating: images/ID_7501E5.png
#   inflating: images/ID_4D2E7B.png
#   inflating: images/ID_147702.png
#   inflating: images/ID_B20BB9.png
#   inflating: images/ID_491442.png
#   inflating: images/ID_9A3D45.png
#   inflating: images/ID_FE2D01.png
#   inflating: images/ID_0188E8.png
#   inflating: images/ID_B571EC.png
#   inflating: images/ID_A58149.png
#   inflating: images/ID_FB2FCD.png
#   inflating: images/ID_160C88.png
#   inflating: images/ID_AE5E3C.png
#   inflating: images/ID_A42A59.png
#   inflating: images/ID_9ADEB8.png
#   inflating: images/ID_C54E78.png
#   inflating: images/ID_0E095E.png
#   inflating: images/ID_2AC240.png
#   inflating: images/ID_2B6D65.png
#   inflating: images/ID_C44E50.png
#   inflating: images/ID_4F2848.png
#   inflating: images/ID_568052.png
#   inflating: images/ID_0A0A0C.png
#   inflating: images/ID_97AF4F.png
#   inflating: images/ID_83F97F.png
#   inflating: images/ID_A113C1.png
#   inflating: images/ID_A3FB4F.png
#   inflating: images/ID_7D771E.png
#   inflating: images/ID_DABD8D.png
#   inflating: images/ID_2BCAB9.png
# Archive:  images-20251223T085919Z-3-002.zip
#   inflating: images/ID_82C255.png
#   inflating: images/ID_2F29B6.png
#   inflating: images/ID_1896A3.png
#   inflating: images/ID_F47330.png
#   inflating: images/ID_1E1D18.png
#   inflating: images/ID_A7D8AE.png
#   inflating: images/ID_3473DE.png
#   inflating: images/ID_36A169.png
#   inflating: images/ID_0F2C9A.png
#   inflating: images/ID_6EB6E7.png
#   inflating: images/ID_285F89.png
#   inflating: images/ID_9DA187.png
#   inflating: images/ID_3EB71F.png
#   inflating: images/ID_FEAB05.png
#   inflating: images/ID_884D79.png
#   inflating: images/ID_A8240C.png
#   inflating: images/ID_16E6A3.png
#   inflating: images/ID_00E26A.png
#   inflating: images/ID_4588E6.png
#   inflating: images/ID_55B192.png
#   inflating: images/ID_E22312.png
#   inflating: images/ID_2B38C2.png
#   inflating: images/ID_8A3363.png
#   inflating: images/ID_09C6C3.png
#   inflating: images/ID_F19700.png
#   inflating: images/ID_208E43.png
#   inflating: images/ID_A1D501.png
#   inflating: images/ID_E8B1CB.png
#   inflating: images/ID_DF0AAB.png
#   inflating: images/ID_45F31D.png
#   inflating: images/ID_ABEA47.png
#   inflating: images/ID_6E7D2D.png
#   inflating: images/ID_0C048B.png
#   inflating: images/ID_FD06B8.png
#   inflating: images/ID_8CE679.png
#   inflating: images/ID_38CA89.png
#   inflating: images/ID_571E0F.png
#   inflating: images/ID_69A5B5.png
#   inflating: images/ID_F7F580.png
#   inflating: images/ID_C21002.png
#   inflating: images/ID_184260.png
#   inflating: images/ID_47A658.png
#   inflating: images/ID_FE709C.png
#   inflating: images/ID_801C14.png
#   inflating: images/ID_678A14.png
#   inflating: images/ID_C3E0C6.png
#   inflating: images/ID_4A213D.png
#   inflating: images/ID_8248A9.png
#   inflating: images/ID_FD2C5E.png
#   inflating: images/ID_7C9D0B.png
#   inflating: images/ID_DD7727.png
#   inflating: images/ID_C7635B.png
#   inflating: images/ID_3FE78A.png
#   inflating: images/ID_FFEED8.png
#   inflating: images/ID_B59C67.png
#   inflating: images/ID_0EEC27.png
#   inflating: images/ID_3B712D.png
#   inflating: images/ID_C60D06.png
#   inflating: images/ID_C9F95A.png
#   inflating: images/ID_C6036A.png
#   inflating: images/ID_E58CC5.png
#   inflating: images/ID_9C3B18.png
#   inflating: images/ID_E19347.png
#   inflating: images/ID_20D135.png
#   inflating: images/ID_D6EF5F.png
#   inflating: images/ID_8597A6.png
#   inflating: images/ID_C667D5.png
#   inflating: images/ID_4DA040.png
#   inflating: images/ID_2CFD45.png
#   inflating: images/ID_AF21D0.png
#   inflating: images/ID_3A15C7.png
#   inflating: images/ID_8F1D43.png
#   inflating: images/ID_B9D487.png
#   inflating: images/ID_A01607.png
#   inflating: images/ID_D6723E.png
#   inflating: images/ID_DB2B41.png
#   inflating: images/ID_A5E0FF.png
#   inflating: images/ID_6A2FEE.png
#   inflating: images/ID_41BFD2.png
#   inflating: images/ID_AACE49.png
#   inflating: images/ID_03F544.png
#   inflating: images/ID_4E2545.png
#   inflating: images/ID_1E6E0A.png
#   inflating: images/ID_68B1FB.png
#   inflating: images/ID_754DDA.png
#   inflating: images/ID_C6BFF6.png
#   inflating: images/ID_A26398.png
#   inflating: images/ID_818F46.png
#   inflating: images/ID_D91D1B.png
#   inflating: images/ID_B1563A.png
#   inflating: images/ID_E5E63D.png
#   inflating: images/ID_A1519D.png
#   inflating: images/ID_DC58E3.png
#   inflating: images/ID_4F16C8.png
#   inflating: images/ID_062DDB.png
#   inflating: images/ID_36A16A.png
#   inflating: images/ID_8A1E80.png
#   inflating: images/ID_8B4066.png
#   inflating: images/ID_2CBCA4.png
#   inflating: images/ID_9F3640.png
#   inflating: images/ID_43BAA6.png
#   inflating: images/ID_460726.png
#   inflating: images/ID_708F3C.png
#   inflating: images/ID_390E98.png
#   inflating: images/ID_731C83.png
#   inflating: images/ID_4A0814.png
#   inflating: images/ID_FC2C7C.png
#   inflating: images/ID_B4D168.png
#   inflating: images/ID_DB576A.png
#   inflating: images/ID_2290A7.png
#   inflating: images/ID_A2137A.png
#   inflating: images/ID_53ADAF.png
#   inflating: images/ID_31857B.png
#   inflating: images/ID_522A9A.png
#   inflating: images/ID_299A23.png
#   inflating: images/ID_F4DD76.png
#   inflating: images/ID_D8700C.png
#   inflating: images/ID_6C340F.png
#   inflating: images/ID_43DD49.png
#   inflating: images/ID_1B0114.png
#   inflating: images/ID_4CA827.png
#   inflating: images/ID_7CCE53.png
#   inflating: images/ID_A89CF5.png
#   inflating: images/ID_53C041.png
#   inflating: images/ID_5055CB.png
#   inflating: images/ID_7FEC30.png
#   inflating: images/ID_CD89FE.png
#   inflating: images/ID_456AC9.png
#   inflating: images/ID_BDB106.png
#   inflating: images/ID_58C548.png
#   inflating: images/ID_D736BB.png
#   inflating: images/ID_6D70CB.png
#   inflating: images/ID_537D9B.png
#   inflating: images/ID_9AC403.png
#   inflating: images/ID_1019C8.png
#   inflating: images/ID_20B5E1.png
#   inflating: images/ID_A0E2A2.png
#   inflating: images/ID_EDDB90.png
#   inflating: images/ID_AFDEC7.png
#   inflating: images/ID_A34BAC.png
#   inflating: images/ID_B9141A.png
#   inflating: images/ID_380673.png
#   inflating: images/ID_E17184.png
#   inflating: images/ID_021BBC.png
#   inflating: images/ID_995E1F.png
#   inflating: images/ID_83FA5A.png
#   inflating: images/ID_27ED0F.png
#   inflating: images/ID_157977.png
#   inflating: images/ID_CE5140.png
#   inflating: images/ID_E515DF.png
#   inflating: images/ID_5D616D.png
#   inflating: images/ID_65CC2C.png
#   inflating: images/ID_93D656.png
#   inflating: images/ID_82B8A3.png
#   inflating: images/ID_076828.png
#   inflating: images/ID_D7322E.png
#   inflating: images/ID_238733.png
#   inflating: images/ID_B8C37E.png
#   inflating: images/ID_7F975A.png
#   inflating: images/ID_AA68C7.png
#   inflating: images/ID_158796.png
#   inflating: images/ID_84D200.png
#   inflating: images/ID_883E88.png
#   inflating: images/ID_08FE26.png
#   inflating: images/ID_F33BA1.png
#   inflating: images/ID_298923.png
#   inflating: images/ID_FED333.png
#   inflating: images/ID_6B1800.png
#   inflating: images/ID_A9B7BA.png
#   inflating: images/ID_1E48C4.png
#   inflating: images/ID_FBA9D8.png
#   inflating: images/ID_24146D.png
#   inflating: images/ID_31B3B3.png
#   inflating: images/ID_9AB0D8.png
#   inflating: images/ID_38DB3A.png
# Archive:  images-20251223T085919Z-3-003.zip
#   inflating: images/ID_03E070.png
#   inflating: images/ID_EF50C3.png
#   inflating: images/ID_934815.png
#   inflating: images/ID_692F93.png
#   inflating: images/ID_7B13B2.png
#   inflating: images/ID_4FAC9B.png
#   inflating: images/ID_0B8AFF.png
#   inflating: images/ID_A1140A.png
#   inflating: images/ID_990827.png
#   inflating: images/ID_FEC8D4.png
#   inflating: images/ID_860320.png
#   inflating: images/ID_C32D9B.png
#   inflating: images/ID_DF6D23.png
#   inflating: images/ID_D93ED5.png
#   inflating: images/ID_924644.png
#   inflating: images/ID_6AAB12.png
#   inflating: images/ID_FE7EE8.png
#   inflating: images/ID_EC5AA0.png
#   inflating: images/ID_2AB564.png
#   inflating: images/ID_D79AAC.png
#   inflating: images/ID_8F468C.png
#   inflating: images/ID_287E03.png
#   inflating: images/ID_9C0180.png
#   inflating: images/ID_B70683.png
#   inflating: images/ID_437D7D.png
#   inflating: images/ID_C22ABF.png
#   inflating: images/ID_431135.png
#   inflating: images/ID_CA7591.png
#   inflating: images/ID_92977A.png
#   inflating: images/ID_89FCD0.png
#   inflating: images/ID_5C9362.png
#   inflating: images/ID_D70732.png
#   inflating: images/ID_6CFE0E.png
#   inflating: images/ID_D240E3.png
#   inflating: images/ID_E6CB2A.png
#   inflating: images/ID_EEB69A.png
#   inflating: images/ID_0F840B.png
#   inflating: images/ID_EF4E3B.png
#   inflating: images/ID_A3D68B.png
#   inflating: images/ID_1CE927.png
#   inflating: images/ID_CC1AA4.png
#   inflating: images/ID_2BA596.png
#   inflating: images/ID_C8C41C.png
#   inflating: images/ID_6395EB.png
#   inflating: images/ID_3CEF96.png
#   inflating: images/ID_9232FE.png
#   inflating: images/ID_B55EC2.png
#   inflating: images/ID_168908.png
#   inflating: images/ID_92262B.png
#   inflating: images/ID_B7892F.png
#   inflating: images/ID_660229.png
#   inflating: images/ID_4E0CB6.png
#   inflating: images/ID_74BBA2.png
#   inflating: images/ID_58E4D4.png
#   inflating: images/ID_1C1D4D.png
#   inflating: images/ID_8065D0.png
#   inflating: images/ID_64223C.png
#   inflating: images/ID_4B6538.png
#   inflating: images/ID_E744F9.png
#   inflating: images/ID_2F885D.png
#   inflating: images/ID_E820A4.png
#   inflating: images/ID_4DAA3D.png
#   inflating: images/ID_3DF1D4.png
#   inflating: images/ID_043C3D.png
#   inflating: images/ID_9F53D8.png
#   inflating: images/ID_1CC363.png
#   inflating: images/ID_D2ED45.png
#   inflating: images/ID_0D0871.png
#   inflating: images/ID_1F4477.png
#   inflating: images/ID_1E056D.png
#   inflating: images/ID_6D0F84.png
#   inflating: images/ID_D045C5.png
#   inflating: images/ID_23CE18.png
#   inflating: images/ID_8D6DC3.png
#   inflating: images/ID_3E89EB.png
#   inflating: images/ID_90794E.png
#   inflating: images/ID_C4015B.png
#   inflating: images/ID_CBB6A3.png
#   inflating: images/ID_CCC0AA.png
#   inflating: images/ID_DA0D11.png
#   inflating: images/ID_E205EE.png
#   inflating: images/ID_A64C94.png
#   inflating: images/ID_430C36.png
#   inflating: images/ID_A4300B.png
#   inflating: images/ID_ACF4B8.png
#   inflating: images/ID_BEA595.png
#   inflating: images/ID_8B5040.png
#   inflating: images/ID_AA169B.png
#   inflating: images/ID_24896E.png
#   inflating: images/ID_7634EA.png
#   inflating: images/ID_F47D0A.png
#   inflating: images/ID_C8FBBC.png
#   inflating: images/ID_621461.png
#   inflating: images/ID_7FA732.png
#   inflating: images/ID_061412.png
#   inflating: images/ID_018825.png
#   inflating: images/ID_5705E1.png
#   inflating: images/ID_2A9D12.png
#   inflating: images/ID_D56B9F.png
#   inflating: images/ID_8B6DD7.png
#   inflating: images/ID_024D7F.png
#   inflating: images/ID_0EFE32.png
#   inflating: images/ID_B6A108.png
#   inflating: images/ID_C2AEE8.png
#   inflating: images/ID_20AEE3.png
#   inflating: images/ID_7CE328.png
#   inflating: images/ID_0A113E.png
#   inflating: images/ID_1F5089.png
#   inflating: images/ID_F57A2F.png
#   inflating: images/ID_D516B1.png
#   inflating: images/ID_6C3CF7.png
#   inflating: images/ID_4B0250.png
#   inflating: images/ID_210F76.png
#   inflating: images/ID_CFBCE4.png
#   inflating: images/ID_98D6F5.png
#   inflating: images/ID_49C9AD.png
#   inflating: images/ID_AEB313.png
#   inflating: images/ID_7504AD.png
#   inflating: images/ID_51EF18.png
#   inflating: images/ID_1FC214.png
#   inflating: images/ID_DD8EB9.png
#   inflating: images/ID_CA8155.png
#   inflating: images/ID_078719.png
#   inflating: images/ID_43FEAE.png
#   inflating: images/ID_170C94.png
#   inflating: images/ID_67D16D.png
#   inflating: images/ID_22FB0C.png
#   inflating: images/ID_847CC5.png
#   inflating: images/ID_1EFA39.png
#   inflating: images/ID_352407.png
#   inflating: images/ID_92FB0C.png
#   inflating: images/ID_DD4504.png
#   inflating: images/ID_07563A.png
#   inflating: images/ID_4B0A59.png
#   inflating: images/ID_EDE7E2.png
#   inflating: images/ID_DDB306.png
#   inflating: images/ID_A01A03.png
#   inflating: images/ID_A8ABB4.png
#   inflating: images/ID_7D04BB.png
#   inflating: images/ID_3B3DBA.png
#   inflating: images/ID_A96B65.png
#   inflating: images/ID_4558DB.png
#   inflating: images/ID_F9A40A.png
#   inflating: images/ID_704AFE.png
#   inflating: images/ID_B6EDC1.png
#   inflating: images/ID_70C639.png
#   inflating: images/ID_22AC3C.png
#   inflating: images/ID_D61E4B.png
#   inflating: images/ID_821FA7.png
#   inflating: images/ID_C86A7E.png
#   inflating: images/ID_352FE2.png
#   inflating: images/ID_E1E32E.png
#   inflating: images/ID_F45526.png
#   inflating: images/ID_19B650.png
#   inflating: images/ID_AFDA33.png
#   inflating: images/ID_C203D8.png
#   inflating: images/ID_5EC91A.png
#   inflating: images/ID_F8C1F2.png
#   inflating: images/ID_189977.png
#   inflating: images/ID_B6F047.png
#   inflating: images/ID_F3F27A.png
#   inflating: images/ID_F770B6.png
#   inflating: images/ID_EBA0DC.png
#   inflating: images/ID_8F7D80.png
#   inflating: images/ID_8E82AB.png
#   inflating: images/ID_AA942A.png
#   inflating: images/ID_C3C59E.png
#   inflating: images/ID_559CB9.png
#   inflating: images/ID_74071A.png
#   inflating: images/ID_670E8A.png
#   inflating: images/ID_154384.png
#   inflating: images/ID_E7B24B.png
#   inflating: images/ID_8EEFCF.png
#   inflating: images/ID_52720E.png
#   inflating: images/ID_077E29.png
#   inflating: images/ID_CDC0D6.png
# Archive:  images-20251223T085919Z-3-004.zip
#   inflating: images/ID_CEE631.png
#   inflating: images/ID_BEED13.png
#   inflating: images/ID_2CA65F.png
#   inflating: images/ID_598B3E.png
#   inflating: images/ID_8DD48D.png
#   inflating: images/ID_C3E878.png
#   inflating: images/ID_7F24D2.png
#   inflating: images/ID_3C7781.png
#   inflating: images/ID_D07E70.png
#   inflating: images/ID_FC4930.png
#   inflating: images/ID_9F396F.png
#   inflating: images/ID_4B04A6.png
#   inflating: images/ID_35CF86.png
#   inflating: images/ID_CBCB58.png
#   inflating: images/ID_573703.png
#   inflating: images/ID_BA2FD3.png
#   inflating: images/ID_2D6CC4.png
#   inflating: images/ID_B2F627.png
#   inflating: images/ID_02A32A.png
#   inflating: images/ID_6A10BB.png
#   inflating: images/ID_B534BA.png
#   inflating: images/ID_25DDC0.png
#   inflating: images/ID_A66658.png
#   inflating: images/ID_2421FC.png
#   inflating: images/ID_5B69B9.png
#   inflating: images/ID_5EF698.png
#   inflating: images/ID_F2FC99.png
#   inflating: images/ID_0D0FD7.png
#   inflating: images/ID_89F0FD.png
#   inflating: images/ID_6FAA80.png
#   inflating: images/ID_98B297.png
#   inflating: images/ID_F64EAC.png
#   inflating: images/ID_A1D33D.png
#   inflating: images/ID_F61D69.png
#   inflating: images/ID_E0EC45.png
#   inflating: images/ID_5737C6.png
#   inflating: images/ID_C042F4.png
#   inflating: images/ID_8D3BBA.png
#   inflating: images/ID_556F39.png
#   inflating: images/ID_55A7CF.png
#   inflating: images/ID_E0CF1F.png
#   inflating: images/ID_5A4B25.png
#   inflating: images/ID_59B90E.png
#   inflating: images/ID_9A9687.png
#   inflating: images/ID_A516A8.png
#   inflating: images/ID_851DDF.png
#   inflating: images/ID_BBF94B.png
#   inflating: images/ID_6C524F.png
#   inflating: images/ID_B83AAC.png
#   inflating: images/ID_FCCB60.png
#   inflating: images/ID_550A14.png
#   inflating: images/ID_06EB61.png
#   inflating: images/ID_FE73F6.png
#   inflating: images/ID_158F30.png
#   inflating: images/ID_496E05.png
#   inflating: images/ID_31839B.png
#   inflating: images/ID_950A41.png
#   inflating: images/ID_C2626D.png
#   inflating: images/ID_37F0E8.png
#   inflating: images/ID_DF877F.png
#   inflating: images/ID_94F6D7.png
#   inflating: images/ID_846C26.png
#   inflating: images/ID_26E359.png
#   inflating: images/ID_34ED06.png
#   inflating: images/ID_D296C1.png
#   inflating: images/ID_AB88B1.png
#   inflating: images/ID_07CDFD.png
#   inflating: images/ID_D86EA6.png
#   inflating: images/ID_A8E864.png
#   inflating: images/ID_92C8C9.png
#   inflating: images/ID_389BC7.png
#   inflating: images/ID_6A9AED.png
#   inflating: images/ID_FB8970.png
#   inflating: images/ID_8F121C.png
#   inflating: images/ID_0F49C8.png
#   inflating: images/ID_DB8E1A.png
#   inflating: images/ID_16A5CD.png
#   inflating: images/ID_854D9F.png
#   inflating: images/ID_E70611.png
#   inflating: images/ID_BC6DC4.png
#   inflating: images/ID_6EA2EF.png
#   inflating: images/ID_F76640.png
#   inflating: images/ID_3B5DCA.png
#   inflating: images/ID_D39577.png
#   inflating: images/ID_46BA9F.png
#   inflating: images/ID_872488.png
#   inflating: images/ID_7F100B.png
#   inflating: images/ID_53E3A7.png
#   inflating: images/ID_F71849.png
#   inflating: images/ID_E5F6AD.png
#   inflating: images/ID_FCCB3C.png
#   inflating: images/ID_EDFBE1.png
#   inflating: images/ID_F73B76.png
#   inflating: images/ID_EDA80A.png
#   inflating: images/ID_8E6B42.png
#   inflating: images/ID_320722.png
#   inflating: images/ID_41AE36.png
#   inflating: images/ID_4EA06F.png
#   inflating: images/ID_819F46.png
#   inflating: images/ID_C058F5.png
#   inflating: images/ID_05F971.png
#   inflating: images/ID_FE131D.png
#   inflating: images/ID_ADDFA9.png
#   inflating: images/ID_0D7DE1.png
#   inflating: images/ID_289DFF.png
#   inflating: images/ID_C8ED21.png
#   inflating: images/ID_C52F1B.png
#   inflating: images/ID_BAC916.png
#   inflating: images/ID_01386B.png
#   inflating: images/ID_AC1DD2.png
#   inflating: images/ID_C24CD7.png
#   inflating: images/ID_335F53.png
#   inflating: images/ID_9B04D1.png
#   inflating: images/ID_E16542.png
#   inflating: images/ID_8C19F5.png
#   inflating: images/ID_FAA9AF.png
#   inflating: images/ID_539FD5.png
#   inflating: images/ID_01161A.png
#   inflating: images/ID_019D38.png
#   inflating: images/ID_E44FEA.png
#   inflating: images/ID_663682.png
#   inflating: images/ID_918890.png
#   inflating: images/ID_42998C.png
#   inflating: images/ID_7EACB5.png
#   inflating: images/ID_BCBE33.png
#   inflating: images/ID_0DEB1C.png
#   inflating: images/ID_81E74D.png
#   inflating: images/ID_EFE937.png
#   inflating: images/ID_DB85E2.png
#   inflating: images/ID_57AEEE.png
#   inflating: images/ID_0C74B7.png
#   inflating: images/ID_D1C38A.png
#   inflating: images/ID_16C222.png
#   inflating: images/ID_E46DE7.png
#   inflating: images/ID_63DC7E.png
#   inflating: images/ID_74DB12.png
#   inflating: images/ID_3B8A61.png
#   inflating: images/ID_EF0D39.png
#   inflating: images/ID_091D58.png
#   inflating: images/ID_26DD0D.png
#   inflating: images/ID_6E7B33.png
#   inflating: images/ID_350510.png
#   inflating: images/ID_013A00.png
#   inflating: images/ID_0E6597.png
#   inflating: images/ID_CCB098.png
#   inflating: images/ID_84D9EE.png
#   inflating: images/ID_AFF162.png
#   inflating: images/ID_C0E190.png
#   inflating: images/ID_D9FC5B.png
#   inflating: images/ID_69421F.png
#   inflating: images/ID_0BB4AE.png
#   inflating: images/ID_06138B.png
#   inflating: images/ID_1534B7.png
#   inflating: images/ID_3621F1.png
#   inflating: images/ID_9DCB88.png
#   inflating: images/ID_470E7A.png
#   inflating: images/ID_A8ECBA.png
#   inflating: images/ID_CFECDB.png
#   inflating: images/ID_274AD4.png
#   inflating: images/ID_69ADC1.png
#   inflating: images/ID_045117.png
#   inflating: images/ID_979D47.png
#   inflating: images/ID_BD686F.png
#   inflating: images/ID_58A2FC.png
#   inflating: images/ID_A597E5.png
#   inflating: images/ID_D96409.png
#   inflating: images/ID_0336DC.png
#   inflating: images/ID_DC6A70.png
#   inflating: images/ID_38AF86.png
#   inflating: images/ID_08419B.png
#   inflating: images/ID_0AA188.png
#   inflating: images/ID_FC2213.png
#   inflating: images/ID_6CD67D.png
#   inflating: images/ID_084B6F.png
#   inflating: images/ID_9E3CFC.png
#   inflating: images/ID_58AE74.png
# Archive:  images-20251223T085919Z-3-005.zip
#   inflating: images/ID_A2557A.png
#   inflating: images/ID_006F52.png
#   inflating: images/ID_0353AB.png
#   inflating: images/ID_064096.png
#   inflating: images/ID_B73CE3.png
#   inflating: images/ID_0537FB.png
#   inflating: images/ID_A4A042.png
#   inflating: images/ID_63538F.png
#   inflating: images/ID_82F2B3.png
#   inflating: images/ID_0FF39B.png
#   inflating: images/ID_D5CFEA.png
#   inflating: images/ID_30EF30.png
#   inflating: images/ID_0777D5.png
#   inflating: images/ID_5EF0B4.png
#   inflating: images/ID_1FF8A7.png
#   inflating: images/ID_8A0E11.png
#   inflating: images/ID_3DC487.png
#   inflating: images/ID_6C4B76.png
#   inflating: images/ID_BD4C9A.png
#   inflating: images/ID_8D3420.png
#   inflating: images/ID_8FECB2.png
#   inflating: images/ID_903CE9.png
#   inflating: images/ID_15D4E8.png
#   inflating: images/ID_4D5B99.png
#   inflating: images/ID_F22170.png
#   inflating: images/ID_C361BC.png
#   inflating: images/ID_42A0E1.png
#   inflating: images/ID_7EF605.png
#   inflating: images/ID_9461CC.png
#   inflating: images/ID_1C9AC0.png
#   inflating: images/ID_A8F15E.png
#   inflating: images/ID_B1EEC3.png
#   inflating: images/ID_918317.png
#   inflating: images/ID_FA7CDF.png
#   inflating: images/ID_30BB38.png
#   inflating: images/ID_E00DA0.png
#   inflating: images/ID_A5E001.png
#   inflating: images/ID_C41000.png
#   inflating: images/ID_7A614F.png
#   inflating: images/ID_B3E3E3.png
#   inflating: images/ID_8E98D8.png
#   inflating: images/ID_A8BAA5.png
#   inflating: images/ID_3DEF18.png
#   inflating: images/ID_CD0069.png
#   inflating: images/ID_138BB0.png
#   inflating: images/ID_37A749.png
#   inflating: images/ID_BE83AB.png
#   inflating: images/ID_EC5DEC.png
#   inflating: images/ID_5F93F9.png
#   inflating: images/ID_555D67.png
#   inflating: images/ID_BF8229.png
#   inflating: images/ID_976652.png
#   inflating: images/ID_2DACE7.png
#   inflating: images/ID_F9B902.png
#   inflating: images/ID_C8FFE9.png
#   inflating: images/ID_9BE40C.png
#   inflating: images/ID_53FDE9.png
#   inflating: images/ID_24B16F.png
#   inflating: images/ID_65DED5.png
#   inflating: images/ID_428FCA.png
#   inflating: images/ID_1068C6.png
#   inflating: images/ID_FB7B9F.png
#   inflating: images/ID_6ECBDD.png
#   inflating: images/ID_3CEC07.png
#   inflating: images/ID_013D40.png
#   inflating: images/ID_7F6FFA.png
#   inflating: images/ID_E96ED4.png
#   inflating: images/ID_B7B16E.png
#   inflating: images/ID_698D51.png
#   inflating: images/ID_73278A.png
#   inflating: images/ID_2B4492.png
#   inflating: images/ID_814481.png
#   inflating: images/ID_EB160D.png
#   inflating: images/ID_812B4B.png
#   inflating: images/ID_DA4FB5.png
#   inflating: images/ID_8C6744.png
#   inflating: images/ID_F89913.png
#   inflating: images/ID_2723D0.png
#   inflating: images/ID_D1F491.png
#   inflating: images/ID_F4B9EC.png
#   inflating: images/ID_98DCE8.png
#   inflating: images/ID_E2EF52.png
#   inflating: images/ID_65B9EE.png
#   inflating: images/ID_1BB91F.png
#   inflating: images/ID_65658F.png
#   inflating: images/ID_A3C65C.png
#   inflating: images/ID_6974CE.png
#   inflating: images/ID_C7E124.png
#   inflating: images/ID_FA3A3C.png
#   inflating: images/ID_B86E8D.png
#   inflating: images/ID_D2DDEA.png
#   inflating: images/ID_1A5B1E.png
#   inflating: images/ID_A97DA6.png
#   inflating: images/ID_32BB90.png
#   inflating: images/ID_3A835D.png
#   inflating: images/ID_96B9BF.png
#   inflating: images/ID_FBD793.png
#   inflating: images/ID_9778D5.png
#   inflating: images/ID_FE9FC2.png
#   inflating: images/ID_D1FE17.png
#   inflating: images/ID_43EC51.png
#   inflating: images/ID_CF004F.png
#   inflating: images/ID_3988C7.png
#   inflating: images/ID_3EF815.png
#   inflating: images/ID_735B90.png
#   inflating: images/ID_6C8349.png
#   inflating: images/ID_5EF059.png
#   inflating: images/ID_642E92.png
#   inflating: images/ID_DC5689.png
#   inflating: images/ID_C0F168.png
#   inflating: images/ID_6DA900.png
#   inflating: images/ID_283802.png
#   inflating: images/ID_D9D4F4.png
#   inflating: images/ID_F71771.png
#   inflating: images/ID_C0C7C7.png
#   inflating: images/ID_9FD818.png
#   inflating: images/ID_861398.png
#   inflating: images/ID_EB1637.png
#   inflating: images/ID_B53B3A.png
#   inflating: images/ID_072B03.png
#   inflating: images/ID_2F2B26.png
#   inflating: images/ID_766EBC.png
#   inflating: images/ID_EA5D2F.png
#   inflating: images/ID_9A1158.png
#   inflating: images/ID_FC490C.png
#   inflating: images/ID_9F6140.png
#   inflating: images/ID_CAF1A3.png
#   inflating: images/ID_E97EE2.png
#   inflating: images/ID_093F65.png
#   inflating: images/ID_BA3866.png
#   inflating: images/ID_E36985.png
#   inflating: images/ID_A684EC.png
#   inflating: images/ID_0266E3.png
#   inflating: images/ID_A733FA.png
#   inflating: images/ID_71A3CB.png
#   inflating: images/ID_C16A53.png
#   inflating: images/ID_D14220.png
#   inflating: images/ID_6EA9AB.png
#   inflating: images/ID_E555EB.png
#   inflating: images/ID_F4F6DC.png
#   inflating: images/ID_7F1171.png
#   inflating: images/ID_17E621.png
#   inflating: images/ID_A7AEED.png
#   inflating: images/ID_303ED4.png
#   inflating: images/ID_D67D8A.png
#   inflating: images/ID_1C383C.png
#   inflating: images/ID_33E75F.png
#   inflating: images/ID_D64592.png
#   inflating: images/ID_2E65F2.png
#   inflating: images/ID_85422A.png
#   inflating: images/ID_1F0E3D.png
#   inflating: images/ID_ECCBC8.png
#   inflating: images/ID_98F137.png
#   inflating: images/ID_50C3D7.png
#   inflating: images/ID_1FF1DE.png
#   inflating: images/ID_3871BD.png
#   inflating: images/ID_C9F0F8.png
#   inflating: images/ID_390597.png
#   inflating: images/ID_7EABE3.png
#   inflating: images/ID_37693C.png
#   inflating: images/ID_D3D944.png
#   inflating: images/ID_502E4A.png
#   inflating: images/ID_3C59DC.png
#   inflating: images/ID_6F4922.png
#   inflating: images/ID_912D2B.png
#   inflating: images/ID_A02FFD.png
#   inflating: images/ID_70EFDF.png
#   inflating: images/ID_48AB2F.png
#   inflating: images/ID_10A7CD.png
#   inflating: images/ID_7380AD.png
#   inflating: images/ID_F90F2A.png
#   inflating: images/ID_6512BD.png
#   inflating: images/ID_BEB22F.png
#   inflating: images/ID_67E103.png
#   inflating: images/ID_310DCB.png
#   inflating: images/ID_4FFCE0.png
# Archive:  images-20251223T085919Z-3-006.zip
#   inflating: images/ID_C51CE4.png
#   inflating: images/ID_39461A.png
#   inflating: images/ID_877A9B.png
#   inflating: images/ID_B5DC4E.png
#   inflating: images/ID_EBD962.png
#   inflating: images/ID_C3992E.png
#   inflating: images/ID_C20AD4.png
#   inflating: images/ID_C15DA1.png
#   inflating: images/ID_9BF31C.png
#   inflating: images/ID_C5FF25.png
#   inflating: images/ID_996A7F.png
#   inflating: images/ID_26408F.png
#   inflating: images/ID_FE8C15.png
#   inflating: images/ID_6CDD60.png
#   inflating: images/ID_82AA4B.png
#   inflating: images/ID_140F69.png
#   inflating: images/ID_8E296A.png
#   inflating: images/ID_7A5392.png
#   inflating: images/ID_9431C8.png
#   inflating: images/ID_941E1A.png
#   inflating: images/ID_8F8551.png
#   inflating: images/ID_AD61AB.png
#   inflating: images/ID_66808E.png
#   inflating: images/ID_8D5E95.png
#   inflating: images/ID_5C572E.png
#   inflating: images/ID_D947BF.png
#   inflating: images/ID_3CF166.png
#   inflating: images/ID_10A5AB.png
#   inflating: images/ID_E4DA3B.png
#   inflating: images/ID_D1F255.png
#   inflating: images/ID_11B984.png
#   inflating: images/ID_41F1F1.png
#   inflating: images/ID_8CB22B.png
#   inflating: images/ID_EED5AF.png
#   inflating: images/ID_884D24.png
#   inflating: images/ID_4F4ADC.png
#   inflating: images/ID_D64A34.png
#   inflating: images/ID_9FC3D7.png
#   inflating: images/ID_DD4585.png
#   inflating: images/ID_E57C6B.png
#   inflating: images/ID_B2EB73.png
#   inflating: images/ID_233509.png
#   inflating: images/ID_F7E6C8.png
#   inflating: images/ID_11B921.png
#   inflating: images/ID_1AA48F.png
#   inflating: images/ID_54229A.png
#   inflating: images/ID_2A38A4.png
#   inflating: images/ID_F0935E.png
#   inflating: images/ID_CA46C1.png
#   inflating: images/ID_E6B4B2.png
#   inflating: images/ID_FA83A1.png
#   inflating: images/ID_3DD48A.png
#   inflating: images/ID_CE78D1.png
#   inflating: images/ID_E2C0BE.png
#   inflating: images/ID_1905AE.png
#   inflating: images/ID_55743C.png
#   inflating: images/ID_68D30A.png
#   inflating: images/ID_44F683.png
#   inflating: images/ID_8EFB10.png
#   inflating: images/ID_DC82D6.png
#   inflating: images/ID_076A0C.png
#   inflating: images/ID_F457C5.png
#   inflating: images/ID_A9A1D5.png
#   inflating: images/ID_E2230B.png
#   inflating: images/ID_67D96D.png
#   inflating: images/ID_1651CF.png
#   inflating: images/ID_371BCE.png
#   inflating: images/ID_58238E.png
#   inflating: images/ID_6364D3.png
#   inflating: images/ID_ED265B.png
#   inflating: images/ID_FFD52F.png
#   inflating: images/ID_3644A6.png
#   inflating: images/ID_38913E.png
#   inflating: images/ID_9C82C7.png
#   inflating: images/ID_E836D8.png
#   inflating: images/ID_4E732C.png
#   inflating: images/ID_D18F65.png
#   inflating: images/ID_182BE0.png
#   inflating: images/ID_CEDEBB.png
#   inflating: images/ID_1BE3BC.png
#   inflating: images/ID_ABA3B6.png
#   inflating: images/ID_0E0193.png
#   inflating: images/ID_96DA2F.png
#   inflating: images/ID_63923F.png
#   inflating: images/ID_E94550.png
#   inflating: images/ID_705F21.png
#   inflating: images/ID_71AD16.png
#   inflating: images/ID_FA14D4.png
#   inflating: images/ID_19BC91.png
#   inflating: images/ID_F1B6F2.png
#   inflating: images/ID_B7BB35.png
#   inflating: images/ID_788D98.png
#   inflating: images/ID_C81E72.png
#   inflating: images/ID_EB6FDC.png
#   inflating: images/ID_5751EC.png
#   inflating: images/ID_68264B.png
#   inflating: images/ID_AB233B.png
#   inflating: images/ID_19F3CD.png
#   inflating: images/ID_33E807.png
#   inflating: images/ID_688396.png
#   inflating: images/ID_1D7F7A.png
#   inflating: images/ID_EEFC9E.png
#   inflating: images/ID_3D2D8C.png
#   inflating: images/ID_59C330.png
#   inflating: images/ID_84F7E6.png
#   inflating: images/ID_F2201F.png
#   inflating: images/ID_9AD6AA.png
#   inflating: images/ID_F033AB.png
#   inflating: images/ID_F0E52B.png
#   inflating: images/ID_7E7757.png
#   inflating: images/ID_246819.png
#   inflating: images/ID_548731.png
#   inflating: images/ID_E4A622.png
#   inflating: images/ID_8D7D8E.png
#   inflating: images/ID_0A09C8.png
#   inflating: images/ID_9FE859.png
#   inflating: images/ID_0CB929.png
#   inflating: images/ID_577BCC.png
#   inflating: images/ID_069059.png
#   inflating: images/ID_A0A080.png
#   inflating: images/ID_285E19.png
#   inflating: images/ID_F7E905.png
#   inflating: images/ID_357A6F.png
#   inflating: images/ID_4734BA.png
#   inflating: images/ID_892C91.png
#   inflating: images/ID_C4B31C.png
#   inflating: images/ID_42E7AA.png
#   inflating: images/ID_363663.png
#   inflating: images/ID_2B24D4.png
#   inflating: images/ID_49182F.png
#   inflating: images/ID_816B11.png
#   inflating: images/ID_25B282.png
#   inflating: images/ID_7250EB.png
#   inflating: images/ID_ABD815.png
#   inflating: images/ID_F74909.png
#   inflating: images/ID_85FC37.png
#   inflating: images/ID_087408.png
#   inflating: images/ID_D840CC.png
#   inflating: images/ID_ACC3E0.png
#   inflating: images/ID_F0ADC8.png
#   inflating: images/ID_677E09.png
#   inflating: images/ID_AD13A2.png
#   inflating: images/ID_92CC22.png
#   inflating: images/ID_A8C88A.png
#   inflating: images/ID_72DA7F.png
#   inflating: images/ID_46922A.png
#   inflating: images/ID_621BF6.png
#   inflating: images/ID_D81F9C.png
#   inflating: images/ID_00EC53.png
#   inflating: images/ID_CB70AB.png
#   inflating: images/ID_060AD9.png
#   inflating: images/ID_959A55.png
#   inflating: images/ID_67F7FB.png
#   inflating: images/ID_114193.png
#   inflating: images/ID_5EA164.png
#   inflating: images/ID_C39986.png
#   inflating: images/ID_DBE272.png
#   inflating: images/ID_51D92B.png
#   inflating: images/ID_93DB85.png
#   inflating: images/ID_B4A528.png
#   inflating: images/ID_821612.png
#   inflating: images/ID_4E4B5F.png
#   inflating: images/ID_82CEC9.png
#   inflating: images/ID_2F37D1.png
#   inflating: images/ID_6ACA97.png
#   inflating: images/ID_2050E0.png
#   inflating: images/ID_9B8619.png
#   inflating: images/ID_F29C21.png
#   inflating: images/ID_288CC0.png
#   inflating: images/ID_99BCFC.png
#   inflating: images/ID_A4F236.png
#   inflating: images/ID_9B698E.png
#   inflating: images/ID_C6E19E.png
#   inflating: images/ID_142949.png
#   inflating: images/ID_8D317B.png
# Archive:  images-20251223T085919Z-3-007.zip
#   inflating: images/ID_03AFDB.png
#   inflating: images/ID_C06D06.png
#   inflating: images/ID_68053A.png
#   inflating: images/ID_02E74F.png
#   inflating: images/ID_B1D10E.png
#   inflating: images/ID_5F2C22.png
#   inflating: images/ID_D58072.png
#   inflating: images/ID_6C2979.png
#   inflating: images/ID_7C590F.png
#   inflating: images/ID_EDDEA8.png
#   inflating: images/ID_7DCD34.png
#   inflating: images/ID_3D8E28.png
#   inflating: images/ID_7FE1F8.png
#   inflating: images/ID_3328BD.png
#   inflating: images/ID_28DD2C.png
#   inflating: images/ID_185E65.png
#   inflating: images/ID_A87FF6.png
#   inflating: images/ID_CFA086.png
#   inflating: images/ID_07C580.png
#   inflating: images/ID_45C48C.png
#   inflating: images/ID_3295C7.png
#   inflating: images/ID_CF6735.png
#   inflating: images/ID_ED3D2C.png
#   inflating: images/ID_170000.png
#   inflating: images/ID_B337E8.png
#   inflating: images/ID_218A0A.png
#   inflating: images/ID_138597.png
#   inflating: images/ID_BBCBFF.png
#   inflating: images/ID_2291D2.png
#   inflating: images/ID_766D85.png
#   inflating: images/ID_6E2713.png
#   inflating: images/ID_6766AA.png
#   inflating: images/ID_6F2268.png
#   inflating: images/ID_8EBDA5.png
#   inflating: images/ID_17C276.png
#   inflating: images/ID_263373.png
#   inflating: images/ID_DACA41.png
#   inflating: images/ID_AD972F.png
#   inflating: images/ID_A5BFC9.png
#   inflating: images/ID_4A47D2.png
#   inflating: images/ID_C5AB0B.png
#   inflating: images/ID_2DEA61.png
#   inflating: images/ID_6E0721.png
#   inflating: images/ID_0F28B5.png
#   inflating: images/ID_C9892A.png
#   inflating: images/ID_FAE0B2.png
#   inflating: images/ID_3AD7C2.png
#   inflating: images/ID_EC8CE6.png
#   inflating: images/ID_4F6FFE.png
#   inflating: images/ID_01F78B.png
#   inflating: images/ID_443CB0.png
#   inflating: images/ID_C45147.png
#   inflating: images/ID_E995F9.png
#   inflating: images/ID_258BE1.png
#   inflating: images/ID_EAE27D.png
#   inflating: images/ID_248E84.png
#   inflating: images/ID_F38762.png
#   inflating: images/ID_FFEABD.png
#   inflating: images/ID_0FF803.png
#   inflating: images/ID_B056EB.png
#   inflating: images/ID_34173C.png
#   inflating: images/ID_53C3BC.png
#   inflating: images/ID_31FEFC.png
#   inflating: images/ID_6F3EF7.png
#   inflating: images/ID_36660E.png
#   inflating: images/ID_BCA82E.png
#   inflating: images/ID_F76A89.png
#   inflating: images/ID_9DE6D1.png
#   inflating: images/ID_76DC61.png
#   inflating: images/ID_DC912A.png
#   inflating: images/ID_5B8ADD.png
#   inflating: images/ID_F1C159.png
#   inflating: images/ID_66F041.png
#   inflating: images/ID_EC8956.png
#   inflating: images/ID_758874.png
#   inflating: images/ID_DF7F28.png
#   inflating: images/ID_7750CA.png
#   inflating: images/ID_202CB9.png
#   inflating: images/ID_1ECFB4.png
#   inflating: images/ID_A67F09.png
#   inflating: images/ID_8DF707.png
#   inflating: images/ID_04ECB1.png
#   inflating: images/ID_5C0492.png
#   inflating: images/ID_B0B183.png
#   inflating: images/ID_185C29.png
#   inflating: images/ID_A53240.png
#   inflating: images/ID_02522A.png
#   inflating: images/ID_97E852.png
#   inflating: images/ID_FDE926.png
#   inflating: images/ID_9CFDF1.png
#   inflating: images/ID_B137FD.png
#   inflating: images/ID_E4BB4C.png
#   inflating: images/ID_45FBC6.png
#   inflating: images/ID_5FD0B3.png
#   inflating: images/ID_CCB1D4.png
#   inflating: images/ID_2B8A61.png
#   inflating: images/ID_8C7BBB.png
#   inflating: images/ID_08B255.png
#   inflating: images/ID_38B3EF.png
#   inflating: images/ID_28F0B8.png
#   inflating: images/ID_B9228E.png
#   inflating: images/ID_3A0772.png
#   inflating: images/ID_B7EE6F.png
#   inflating: images/ID_FC8001.png
#   inflating: images/ID_E0C641.png
#   inflating: images/ID_298F95.png
#   inflating: images/ID_A49E94.png
#   inflating: images/ID_F79921.png
#   inflating: images/ID_795C7A.png
#   inflating: images/ID_DA8CE5.png
#   inflating: images/ID_58D4D1.png
#   inflating: images/ID_18D804.png
#   inflating: images/ID_C75B6F.png
#   inflating: images/ID_55B37C.png
#   inflating: images/ID_EECCA5.png
#   inflating: images/ID_A5CDD4.png
#   inflating: images/ID_35F4A8.png
#   inflating: images/ID_AB817C.png
#   inflating: images/ID_8BF121.png
#   inflating: images/ID_149E96.png
#   inflating: images/ID_A8849B.png
#   inflating: images/ID_C4CA42.png
#   inflating: images/ID_9C838D.png
#   inflating: images/ID_6C9882.png
#   inflating: images/ID_43FA7F.png
#   inflating: images/ID_F5DEAE.png
#   inflating: images/ID_2A79EA.png
#   inflating: images/ID_F5F859.png
#   inflating: images/ID_004114.png
#   inflating: images/ID_A1D0C6.png
#   inflating: images/ID_B5B41F.png
#   inflating: images/ID_839AB4.png
#   inflating: images/ID_BE3159.png
#   inflating: images/ID_9B70E8.png
#   inflating: images/ID_D7A728.png
#   inflating: images/ID_CA9C26.png
#   inflating: images/ID_08C543.png
#   inflating: images/ID_15DE21.png
#   inflating: images/ID_EAAE33.png
#   inflating: images/ID_2BB232.png
#   inflating: images/ID_99C5E0.png
#   inflating: images/ID_B6D767.png
#   inflating: images/ID_D6BAF6.png
#   inflating: images/ID_E07413.png
#   inflating: images/ID_E2A2DC.png
#   inflating: images/ID_06997F.png
#   inflating: images/ID_42E77B.png
#   inflating: images/ID_13F989.png
#   inflating: images/ID_4C5BDE.png
#   inflating: images/ID_109A0C.png
#   inflating: images/ID_3FE94A.png
#   inflating: images/ID_362E80.png
#   inflating: images/ID_94C7BB.png
#   inflating: images/ID_A5771B.png
#   inflating: images/ID_CFEE39.png
#   inflating: images/ID_250CF8.png
#   inflating: images/ID_E5841D.png
#   inflating: images/ID_F340F1.png
#   inflating: images/ID_26657D.png
#   inflating: images/ID_2AFE45.png
#   inflating: images/ID_7CBBC4.png
#   inflating: images/ID_6DA37D.png
#   inflating: images/ID_854D6F.png
#   inflating: images/ID_88AE63.png
#   inflating: images/ID_4C56FF.png
#   inflating: images/ID_19CA14.png
#   inflating: images/ID_0D3180.png
#   inflating: images/ID_9CC138.png
#   inflating: images/ID_03C6B0.png
#   inflating: images/ID_841172.png
#   inflating: images/ID_D709F3.png
#   inflating: images/ID_5D44EE.png
#   inflating: images/ID_9CF81D.png
#   inflating: images/ID_72B32A.png
#   inflating: images/ID_9B72E3.png
# Archive:  images-20251223T085919Z-3-008.zip
#   inflating: images/ID_167909.png
#   inflating: images/ID_9872ED.png
#   inflating: images/ID_1728EF.png
#   inflating: images/ID_040259.png
#   inflating: images/ID_D490D7.png
#   inflating: images/ID_577EF1.png
#   inflating: images/ID_BF6276.png
#   inflating: images/ID_40008B.png
#   inflating: images/ID_0584CE.png
#   inflating: images/ID_291597.png
#   inflating: images/ID_47D1E9.png
#   inflating: images/ID_7143D7.png
#   inflating: images/ID_A9A665.png
#   inflating: images/ID_DF263D.png
#   inflating: images/ID_0FCBC6.png
#   inflating: images/ID_F4BE00.png
#   inflating: images/ID_07A96B.png
#   inflating: images/ID_13FE9D.png
#   inflating: images/ID_217EED.png
#   inflating: images/ID_61B4A6.png
#   inflating: images/ID_2823F4.png
#   inflating: images/ID_E7F8A7.png
#   inflating: images/ID_9DFCD5.png
#   inflating: images/ID_432ACA.png
#   inflating: images/ID_685545.png
#   inflating: images/ID_B4288D.png
#   inflating: images/ID_A86C45.png
#   inflating: images/ID_5807A6.png
#   inflating: images/ID_44C4C1.png
#   inflating: images/ID_E3796A.png
#   inflating: images/ID_2A084E.png
#   inflating: images/ID_5878A7.png
#   inflating: images/ID_67C6A1.png
#   inflating: images/ID_F85454.png
#   inflating: images/ID_0F9661.png
#   inflating: images/ID_8F14E4.png
#   inflating: images/ID_7F39F8.png
#   inflating: images/ID_DC6A64.png
#   inflating: images/ID_05049E.png
#   inflating: images/ID_F9028F.png
#   inflating: images/ID_1AFA34.png
#   inflating: images/ID_07E1CD.png
#   inflating: images/ID_13F320.png
#   inflating: images/ID_75FC09.png
#   inflating: images/ID_13F3CF.png
#   inflating: images/ID_E8C065.png
#   inflating: images/ID_69CB3E.png
#   inflating: images/ID_5DD9DB.png
#   inflating: images/ID_632CEE.png
#   inflating: images/ID_08D986.png
#   inflating: images/ID_7BCDF7.png
#   inflating: images/ID_82489C.png
#   inflating: images/ID_6BC24F.png
#   inflating: images/ID_B2EEB7.png
#   inflating: images/ID_AE0EB3.png
#   inflating: images/ID_C74D97.png
#   inflating: images/ID_D6C651.png
#   inflating: images/ID_8B16EB.png
#   inflating: images/ID_301AD0.png
#   inflating: images/ID_17D63B.png
#   inflating: images/ID_32B30A.png
#   inflating: images/ID_2F5570.png
#   inflating: images/ID_500E75.png
#   inflating: images/ID_68CE19.png
#   inflating: images/ID_4E0928.png
#   inflating: images/ID_E49B8B.png
#   inflating: images/ID_051E4E.png
#   inflating: images/ID_5E9F92.png
#   inflating: images/ID_49AE49.png
#   inflating: images/ID_608159.png
#   inflating: images/ID_3416A7.png
#   inflating: images/ID_5E3881.png
#   inflating: images/ID_AFD483.png
#   inflating: images/ID_E56954.png
#   inflating: images/ID_FF4D5F.png
#   inflating: images/ID_757B50.png
#   inflating: images/ID_45645A.png
#   inflating: images/ID_AC627A.png
#   inflating: images/ID_37BC2F.png
#   inflating: images/ID_B73DFE.png
#   inflating: images/ID_7F1DE2.png
#   inflating: images/ID_349389.png
#   inflating: images/ID_48AEDB.png
#   inflating: images/ID_D554F7.png
#   inflating: images/ID_14BFA6.png
#   inflating: images/ID_7F5D04.png
#   inflating: images/ID_EF575E.png
#   inflating: images/ID_3A066B.png
#   inflating: images/ID_D82C8D.png
#   inflating: images/ID_875715.png
#   inflating: images/ID_115F89.png
#   inflating: images/ID_5F0F5E.png
#   inflating: images/ID_85D8CE.png
#   inflating: images/ID_D34AB1.png
#   inflating: images/ID_AAB323.png
#   inflating: images/ID_B1A59B.png
#   inflating: images/ID_D09BF4.png
#   inflating: images/ID_4C27CE.png
#   inflating: images/ID_605FF7.png
#   inflating: images/ID_647BBA.png
#   inflating: images/ID_8F5329.png
#   inflating: images/ID_069D3B.png
#   inflating: images/ID_86B122.png
#   inflating: images/ID_C9E107.png
#   inflating: images/ID_96EA64.png
#   inflating: images/ID_8C235F.png
#   inflating: images/ID_764796.png
#   inflating: images/ID_8FE009.png
#   inflating: images/ID_A76088.png
#   inflating: images/ID_B3967A.png
#   inflating: images/ID_192FC0.png
#   inflating: images/ID_E2C420.png

# %% [markdown]
# ### Mount Drive and Define Paths

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Train = "/content/drive/MyDrive/Mission Capstone/Dataset/Train.csv"
Test = "/content/drive/MyDrive/Mission Capstone/Dataset/Test.csv"

DRIVE_IMAGE_PATH = "/content/drive/MyDrive/rice_dataset/images"
LOCAL_IMAGE_PATH = "/content/images"

# %% [markdown]
# ### Copy Images to Local Runtime for Faster Training

# %%
# !rm -rf /content/images
# !cp -r "/content/drive/MyDrive/rice_dataset/images" /content/

# %%
import os

print("Images copied:", len(os.listdir(LOCAL_IMAGE_PATH)))
print("Sample files:", os.listdir(LOCAL_IMAGE_PATH)[:5])
# Out:
# Images copied: 1341
# Sample files: ['ID_380673.png', 'ID_BB04AF.png', 'ID_5D616D.png', 'ID_154384.png', 'ID_3546AB.png']

# %% [markdown]
# ### Load Train and Test Data

# %%
import pandas as pd
import numpy as np

train_df = pd.read_csv(Train)
test_df = pd.read_csv(Test)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
display(train_df.head())
# Out:
# Train shape: (938, 17)
# Test shape: (403, 2)
#           ID Comment  Count  Broken_Count  Long_Count  Medium_Count  \
# 0  ID_556F39   Paddy    957           261         193             0
# 1  ID_AA68C7   White   2009          1022         730             0
# 2  ID_19CA14   Paddy   1062           302         242             0
# 3  ID_92FB0C   Brown   1098           231         812             0
# 4  ID_EAE27D   Brown   1456           529         758             1
#
#    Black_Count  Chalky_Count  Red_Count  Yellow_Count  Green_Count  \
# 0          895             0         62             0            0
# 1          124           791          4             9          551
# 2         1031             0         30             1            0
# 3          180           862         11            44            1
# 4          211          1117         16           110            2
#
#    WK_Length_Average  WK_Width_Average  WK_LW_Ratio_Average  Average_L  \
# 0               9.28              3.18                 3.08      63.00
# 1               6.34              2.13                 3.00      70.36
# 2               9.23              3.15                 3.03      61.32
# 3               7.59              2.57                 2.98      66.48
# 4               7.12              2.31                 3.13      65.97
#
#    Average_a  Average_b
# 0       8.43      31.59
# 1      -2.49      -7.29
# 2       8.13      30.52
# 3      -0.58      12.64
# 4      -0.40      10.86

# %% [markdown]
# ### Detect ID Column and Create Filename Column

# %%
possible_id_cols = ["ID", "id", "image_id", "Image_ID", "filename", "file_name"]
id_col = next((c for c in possible_id_cols if c in train_df.columns), None)

if id_col is None:
    raise ValueError(f"No ID column found. Columns are: {train_df.columns.tolist()}")

print("Using ID column:", id_col)
# Out:
# Using ID column: ID

# %%
# If your images are .png as shown in your notebook
train_df["filename"] = train_df[id_col].astype(str) + ".png"
test_df["filename"] = test_df[id_col].astype(str) + ".png"

# %% [markdown]
# ### Master Link the IDs to the corresponding images

# %%
train_df = train_df[train_df["filename"].apply(lambda x: os.path.exists(os.path.join(LOCAL_IMAGE_PATH, x)))].copy()
test_df  = test_df[test_df["filename"].apply(lambda x: os.path.exists(os.path.join(LOCAL_IMAGE_PATH, x)))].copy()

print("Filtered train shape:", train_df.shape)
print("Filtered test shape :", test_df.shape)
# Out:
# Filtered train shape: (938, 18)
# Filtered test shape : (403, 3)

# %% [markdown]
# ### Define Target Columns

# %%
exclude_cols = [id_col, "filename", "Comment"]

target_cols = [c for c in train_df.columns if c not in exclude_cols]

print("Target columns:", target_cols)
print("Number of targets:", len(target_cols))
# Out:
# Target columns: ['Count', 'Broken_Count', 'Long_Count', 'Medium_Count', 'Black_Count', 'Chalky_Count', 'Red_Count', 'Yellow_Count', 'Green_Count', 'WK_Length_Average', 'WK_Width_Average', 'WK_LW_Ratio_Average', 'Average_L', 'Average_a', 'Average_b']
# Number of targets: 15

# %% [markdown]
# ### Basic Dataset Summary

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10,6)

print("Dataset shape:", train_df.shape)

print("\nMissing values:")
print(train_df[target_cols].isnull().sum())

print("\nStatistical Summary:")
display(train_df[target_cols].describe())
# Out:
# Dataset shape: (938, 18)
#
# Missing values:
# Count                  0
# Broken_Count           0
# Long_Count             0
# Medium_Count           0
# Black_Count            0
# Chalky_Count           0
# Red_Count              0
# Yellow_Count           0
# Green_Count            0
# WK_Length_Average      0
# WK_Width_Average       0
# WK_LW_Ratio_Average    0
# Average_L              0
# Average_a              0
# Average_b              0
# dtype: int64
#
# Statistical Summary:
#               Count  Broken_Count    Long_Count  Medium_Count   Black_Count  \
# count  9.380000e+02  9.380000e+02  9.380000e+02  9.380000e+02  9.380000e+02
# mean  -1.363515e-16  4.734427e-17 -9.468853e-17  6.628197e-18 -7.196328e-17
# std    1.000533e+00  1.000533e+00  1.000533e+00  1.000533e+00  1.000533e+00
# min   -1.669751e+00 -1.150551e+00 -1.889333e+00 -1.969070e-01 -1.259764e+00
# 25%   -7.085686e-01 -5.831664e-01 -1.024316e+00 -1.969070e-01 -9.071283e-01
# 50%   -2.086371e-01 -2.589465e-01  1.843598e-01 -1.969070e-01 -4.271672e-01
# 75%    4.635335e-01  1.966126e-01  8.297694e-01 -3.587930e-02  1.029877e+00
# max    6.559778e+00  8.032679e+00  2.472630e+00  1.816025e+01  2.637498e+00
#
#        Chalky_Count     Red_Count  Yellow_Count   Green_Count  \
# count  9.380000e+02  9.380000e+02  9.380000e+02  9.380000e+02
# mean  -1.136262e-17 -7.575082e-17  2.272525e-17  5.870689e-17
# std    1.000533e+00  1.000533e+00  1.000533e+00  1.000533e+00
# min   -1.045156e+00 -9.050837e-01 -5.593749e-01 -4.503130e-01
# 25%   -1.045156e+00 -7.616850e-01 -5.517067e-01 -4.503130e-01
# 50%   -1.676909e-02 -2.836891e-01 -4.596874e-01 -4.503130e-01
# 75%    8.106441e-01  3.855052e-01 -3.218139e-02 -2.431001e-01
# max    4.517969e+00  6.073657e+00  7.047548e+00  4.661946e+00
#
#        WK_Length_Average  WK_Width_Average  WK_LW_Ratio_Average     Average_L  \
# count       9.380000e+02      9.380000e+02         9.380000e+02  9.380000e+02
# mean        8.711345e-17     -6.703948e-16        -1.568042e-15 -4.317797e-16
# std         1.000533e+00      1.000533e+00         1.000533e+00  1.000533e+00
# min        -2.233194e+00     -2.005914e+00        -3.631943e+00 -5.592652e+00
# 25%        -7.961881e-01     -8.055905e-01        -6.000650e-01 -6.112027e-01
# 50%        -3.609805e-01     -1.787547e-01        -5.143942e-02  3.342765e-02
# 75%         1.106819e+00      8.215151e-01         5.838112e-01  7.108827e-01
# max         2.102459e+00      3.275510e+00         3.067064e+00  2.767767e+00
#
#           Average_a     Average_b
# count  9.380000e+02  9.380000e+02
# mean  -1.515016e-17  7.575082e-17
# std    1.000533e+00  1.000533e+00
# min   -1.489424e+00 -1.794453e+00
# 25%   -8.599740e-01 -1.107562e+00
# 50%   -5.025942e-01 -1.230245e-01
# 75%    9.688884e-01  1.035599e+00
# max    3.435501e+00  1.852925e+00

# %% [markdown]
# ### Distribution of Target Variables

# %%
for col in target_cols:
    plt.figure()
    sns.histplot(train_df[col], bins=30, kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(14,10))

corr = train_df[target_cols].corr()

sns.heatmap(
    corr,
    cmap="coolwarm",
    center=0,
    square=True
)

plt.title("Correlation Between Rice Quality Indicators")
plt.show()

# %% [markdown]
# ### Boxplots to Detect Outliers

# %%
plt.figure(figsize=(15,10))

sns.boxplot(data=train_df[target_cols])

plt.xticks(rotation=90)
plt.title("Outlier Detection in Rice Quality Features")
plt.show()

# %% [markdown]
# ### Grain Count Composition

# %%
grain_structure = [
    "Broken_Count",
    "Long_Count",
    "Medium_Count"
]

train_df[grain_structure].sum().plot(
    kind="bar",
    color=["orange","green","blue"]
)

plt.title("Total Grain Structure Counts")
plt.ylabel("Total Count")
plt.show()

# %% [markdown]
# ### Rice Colour Composition

# %%
color_features = [
    "Black_Count",
    "Chalky_Count",
    "Red_Count",
    "Yellow_Count",
    "Green_Count"
]

train_df[color_features].sum().plot(
    kind="bar",
    color=["black","gray","red","yellow","green"]
)

plt.title("Rice Colour Composition in Dataset")
plt.ylabel("Total Count")
plt.show()

# %% [markdown]
# ### Grain Shape Visualization

# %%
plt.scatter(
    train_df["WK_Length_Average"],
    train_df["WK_Width_Average"],
    alpha=0.5
)

plt.xlabel("Average Grain Length")
plt.ylabel("Average Grain Width")
plt.title("Grain Length vs Width Relationship")

plt.show()

# %% [markdown]
# ### Length-to-Width Ratio Distribution

# %%
sns.histplot(train_df["WK_LW_Ratio_Average"], bins=30, kde=True)

plt.title("Distribution of Grain Length-Width Ratio")
plt.xlabel("Length / Width Ratio")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ### Feature engineering

# %%
train_df["broken_pct"] = train_df["Broken_Count"] / train_df["Count"]
train_df["chalky_pct"] = train_df["Chalky_Count"] / train_df["Count"]
train_df["long_pct"] = train_df["Long_Count"] / train_df["Count"]
train_df["medium_pct"] = train_df["Medium_Count"] / train_df["Count"]

# %% [markdown]
# ### Scale Target Values

# %%
from sklearn.preprocessing import StandardScaler

target_scaler = StandardScaler()
train_df[target_cols] = target_scaler.fit_transform(train_df[target_cols])

# Save scaler for inverse transform later
import joblib
joblib.dump(target_scaler, "/content/drive/MyDrive/Mission Capstone/Dataset/target_scaler.pkl")
# Out:
# ['/content/drive/MyDrive/Mission Capstone/Dataset/target_scaler.pkl']

# %% [markdown]
# ### Data Train / Validation Split

# %%
from sklearn.model_selection import train_test_split

train_split_df, val_split_df = train_test_split(
    train_df,
    test_size=0.2,
    random_state=42
)

print("Train split:", train_split_df.shape)
print("Val split:", val_split_df.shape)
# Out:
# Train split: (750, 22)
# Val split: (188, 22)

# %% [markdown]
# ### Build Image Data Generators

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_split_df,
    directory=LOCAL_IMAGE_PATH,
    x_col="filename",
    y_col=target_cols,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="raw",
    shuffle=True
)

val_generator = val_datagen.flow_from_dataframe(
    dataframe=val_split_df,
    directory=LOCAL_IMAGE_PATH,
    x_col="filename",
    y_col=target_cols,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="raw",
    shuffle=False
)
# Out:
# Found 750 validated image filenames.
# Found 188 validated image filenames.

# %% [markdown]
# ### Build the Model

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

base_model = EfficientNetB0(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze pretrained base first
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)

x = BatchNormalization()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.3)(x)

x = Dense(128, activation="relu")(x)
x = Dropout(0.2)(x)

outputs = Dense(len(target_cols), activation="linear")(x)

model = Model(inputs=base_model.input, outputs=outputs)

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="mse",
    metrics=["mae"]
)

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_2         │ (None, 224, 224,  │          0 │ input_layer_3[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_1     │ (None, 224, 224,  │          7 │ rescaling_2[0][0] │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3         │ (None, 224, 224,  │          0 │ normalization_1[… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 225, 225,  │          0 │ rescaling_3[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 112, 112,  │        864 │ stem_conv_pad[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 112, 112,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 112, 112,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 112, 112,  │        288 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 112, 112,  │        128 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 112, 112,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 112, 112,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 112, 112,  │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 112, 112,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 112, 112,  │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 112, 112,  │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 112, 112,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 113, 113,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 56, 56,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 56, 56,    │        384 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 56, 56,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 56, 56,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 56, 56,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 56, 56,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 56, 56,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 56, 56,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 56, 56,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 56, 56,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 56, 56,    │        576 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 56, 56,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 56, 56,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 56, 56,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 56, 56,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 56, 56,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 56, 56,    │          0 │ block2b_drop[0][… │
# │                     │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 56, 56,    │      3,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 56, 56,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 56, 56,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 59, 59,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 28, 28,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 28, 28,    │        576 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 28, 28,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 28, 28,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 28, 28,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 28, 28,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 28, 28,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 28, 28,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 28, 28,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 28, 28,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 28, 28,    │        960 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 28, 28,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 28, 28,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 28, 28,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 28, 28,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 28, 28,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 28, 28,    │          0 │ block3b_drop[0][… │
# │                     │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 28, 28,    │      9,600 │ block3b_add[0][0] │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 28, 28,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 28, 28,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 29, 29,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 14, 14,    │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 14, 14,    │        960 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 14, 14,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 14, 14,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 240)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 14, 14,    │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 14, 14,    │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 14, 14,    │     38,400 │ block4a_project_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 14, 14,    │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 14, 14,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 14, 14,    │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 14, 14,    │      1,920 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 14, 14,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 14, 14,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 480)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 14, 14,    │     38,400 │ block4b_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 14, 14,    │        320 │ block4b_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 14, 14,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 14, 14,    │          0 │ block4b_drop[0][… │
# │                     │ 80)               │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 14, 14,    │     38,400 │ block4b_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 14, 14,    │      1,920 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 14, 14,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 14, 14,    │      4,320 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 14, 14,    │      1,920 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 14, 14,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 480)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 480) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 14, 14,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 480)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 14, 14,    │     38,400 │ block4c_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 14, 14,    │        320 │ block4c_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 14, 14,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 14, 14,    │          0 │ block4c_drop[0][… │
# │                     │ 80)               │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 14, 14,    │     38,400 │ block4c_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 14, 14,    │      1,920 │ block5a_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 14, 14,    │          0 │ block5a_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv      │ (None, 14, 14,    │     12,000 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 14, 14,    │      1,920 │ block5a_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 14, 14,    │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 480)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 480) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 480) │     10,080 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 14, 14,    │          0 │ block5a_activati… │
# │ (Multiply)          │ 480)              │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 14, 14,    │     53,760 │ block5a_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 14, 14,    │        448 │ block5a_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 14, 14,    │     75,264 │ block5a_project_… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 14, 14,    │      2,688 │ block5b_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 14, 14,    │          0 │ block5b_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv      │ (None, 14, 14,    │     16,800 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 14, 14,    │      2,688 │ block5b_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 14, 14,    │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 672)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 672) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 14, 14,    │          0 │ block5b_activati… │
# │ (Multiply)          │ 672)              │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 14, 14,    │     75,264 │ block5b_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 14, 14,    │        448 │ block5b_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 14, 14,    │          0 │ block5b_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 14, 14,    │          0 │ block5b_drop[0][… │
# │                     │ 112)              │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 14, 14,    │     75,264 │ block5b_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 14, 14,    │      2,688 │ block5c_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 14, 14,    │          0 │ block5c_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv      │ (None, 14, 14,    │     16,800 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 14, 14,    │      2,688 │ block5c_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 14, 14,    │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 672)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 672) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 14, 14,    │          0 │ block5c_activati… │
# │ (Multiply)          │ 672)              │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 14, 14,    │     75,264 │ block5c_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 14, 14,    │        448 │ block5c_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 14, 14,    │          0 │ block5c_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 14, 14,    │          0 │ block5c_drop[0][… │
# │                     │ 112)              │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 14, 14,    │     75,264 │ block5c_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 14, 14,    │      2,688 │ block6a_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 14, 14,    │          0 │ block6a_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv_pad  │ (None, 17, 17,    │          0 │ block6a_expand_a… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv      │ (None, 7, 7, 672) │     16,800 │ block6a_dwconv_p… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 7, 7, 672) │      2,688 │ block6a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 7, 7, 672) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 672)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 672) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 672) │     19,488 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 7, 7, 672) │          0 │ block6a_activati… │
# │ (Multiply)          │                   │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 7, 7, 192) │    129,024 │ block6a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 7, 7, 192) │        768 │ block6a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 7, 7,      │    221,184 │ block6a_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 7, 7,      │      4,608 │ block6b_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 7, 7,      │          0 │ block6b_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv      │ (None, 7, 7,      │     28,800 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 7, 7,      │      4,608 │ block6b_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 7, 7,      │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 1152)      │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1,      │          0 │ block6b_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1,      │     56,448 │ block6b_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 7, 7,      │          0 │ block6b_activati… │
# │ (Multiply)          │ 1152)             │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 7, 7, 192) │    221,184 │ block6b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 7, 7, 192) │        768 │ block6b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 7, 7, 192) │          0 │ block6b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 7, 7, 192) │          0 │ block6b_drop[0][… │
# │                     │                   │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 7, 7,      │    221,184 │ block6b_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 7, 7,      │      4,608 │ block6c_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 7, 7,      │          0 │ block6c_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv      │ (None, 7, 7,      │     28,800 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 7, 7,      │      4,608 │ block6c_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 7, 7,      │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 1152)      │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1,      │          0 │ block6c_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1,      │     56,448 │ block6c_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 7, 7,      │          0 │ block6c_activati… │
# │ (Multiply)          │ 1152)             │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 7, 7, 192) │    221,184 │ block6c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 7, 7, 192) │        768 │ block6c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 7, 7, 192) │          0 │ block6c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 7, 7, 192) │          0 │ block6c_drop[0][… │
# │                     │                   │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 7, 7,      │    221,184 │ block6c_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 7, 7,      │      4,608 │ block6d_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 7, 7,      │          0 │ block6d_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv      │ (None, 7, 7,      │     28,800 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 7, 7,      │      4,608 │ block6d_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 7, 7,      │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 1152)      │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1,      │          0 │ block6d_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1,      │     56,448 │ block6d_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 7, 7,      │          0 │ block6d_activati… │
# │ (Multiply)          │ 1152)             │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 7, 7, 192) │    221,184 │ block6d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 7, 7, 192) │        768 │ block6d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 7, 7, 192) │          0 │ block6d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 7, 7, 192) │          0 │ block6d_drop[0][… │
# │                     │                   │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_conv │ (None, 7, 7,      │    221,184 │ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 7, 7,      │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 7, 7,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 7, 7,      │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 7, 7,      │      4,608 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 7, 7,      │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 7, 7,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 7, 7, 320) │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 7, 7, 320) │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 7, 7,      │    409,600 │ block7a_project_… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 7, 7,      │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 7, 7,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1280)      │      5,120 │ global_average_p… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256)       │    327,936 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     32,896 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 15)        │      1,935 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,417,458 (16.85 MB)
#  Trainable params: 365,327 (1.39 MB)
#  Non-trainable params: 4,052,131 (15.46 MB)

# %% [markdown]
# ### Add Training Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        min_lr=1e-6
    ),
    ModelCheckpoint(
        "/content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5",
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    )
]

# %% [markdown]
# ### Train the Model

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 1.2241 - mae: 0.8383
# Epoch 1: val_loss improved from inf to 1.10748, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 391s 16s/step - loss: 1.2223 - mae: 0.8378 - val_loss: 1.1075 - val_mae: 0.7714 - learning_rate: 1.0000e-04
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 1.0285 - mae: 0.7916
# Epoch 2: val_loss improved from 1.10748 to 1.10367, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 349s 15s/step - loss: 1.0307 - mae: 0.7919 - val_loss: 1.1037 - val_mae: 0.7724 - learning_rate: 1.0000e-04
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 1.0956 - mae: 0.8025
# Epoch 3: val_loss improved from 1.10367 to 1.10158, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 352s 15s/step - loss: 1.0938 - mae: 0.8020 - val_loss: 1.1016 - val_mae: 0.7736 - learning_rate: 1.0000e-04
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 1.0582 - mae: 0.7849
# Epoch 4: val_loss improved from 1.10158 to 1.09811, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 339s 14s/step - loss: 1.0568 - mae: 0.7846 - val_loss: 1.0981 - val_mae: 0.7725 - learning_rate: 1.0000e-04
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - loss: 1.0196 - mae: 0.7713
# Epoch 5: val_loss improved from 1.09811 to 1.09764, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 365s 16s/step - loss: 1.0192 - mae: 0.7714 - val_loss: 1.0976 - val_mae: 0.7737 - learning_rate: 1.0000e-04
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9770 - mae: 0.7669
# Epoch 6: val_loss improved from 1.09764 to 1.09645, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 355s 15s/step - loss: 0.9782 - mae: 0.7671 - val_loss: 1.0964 - val_mae: 0.7739 - learning_rate: 1.0000e-04
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.9758 - mae: 0.7540
# Epoch 7: val_loss improved from 1.09645 to 1.09440, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 346s 14s/step - loss: 0.9765 - mae: 0.7547 - val_loss: 1.0944 - val_mae: 0.7735 - learning_rate: 1.0000e-04
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 1.0057 - mae: 0.7745
# Epoch 8: val_loss improved from 1.09440 to 1.09250, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 369s 15s/step - loss: 1.0049 - mae: 0.7740 - val_loss: 1.0925 - val_mae: 0.7735 - learning_rate: 1.0000e-04
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 1.0428 - mae: 0.7749
# Epoch 9: val_loss improved from 1.09250 to 1.09196, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 347s 14s/step - loss: 1.0402 - mae: 0.7744 - val_loss: 1.0920 - val_mae: 0.7734 - learning_rate: 1.0000e-04
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9706 - mae: 0.7553
# Epoch 10: val_loss improved from 1.09196 to 1.09025, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 367s 15s/step - loss: 0.9706 - mae: 0.7553 - val_loss: 1.0903 - val_mae: 0.7725 - learning_rate: 1.0000e-04
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.9320 - mae: 0.7491
# Epoch 11: val_loss improved from 1.09025 to 1.09005, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 355s 15s/step - loss: 0.9337 - mae: 0.7495 - val_loss: 1.0901 - val_mae: 0.7715 - learning_rate: 1.0000e-04
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.9536 - mae: 0.7536
# Epoch 12: val_loss improved from 1.09005 to 1.08845, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 352s 15s/step - loss: 0.9543 - mae: 0.7536 - val_loss: 1.0885 - val_mae: 0.7713 - learning_rate: 1.0000e-04
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9727 - mae: 0.7550
# Epoch 13: val_loss improved from 1.08845 to 1.08744, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 362s 15s/step - loss: 0.9721 - mae: 0.7548 - val_loss: 1.0874 - val_mae: 0.7722 - learning_rate: 1.0000e-04
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9702 - mae: 0.7570
# Epoch 14: val_loss improved from 1.08744 to 1.08413, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 352s 15s/step - loss: 0.9694 - mae: 0.7566 - val_loss: 1.0841 - val_mae: 0.7711 - learning_rate: 1.0000e-04
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 1.0056 - mae: 0.7569
# Epoch 15: val_loss improved from 1.08413 to 1.08370, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 365s 15s/step - loss: 1.0036 - mae: 0.7565 - val_loss: 1.0837 - val_mae: 0.7706 - learning_rate: 1.0000e-04
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8848 - mae: 0.7316
# Epoch 16: val_loss improved from 1.08370 to 1.07985, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 365s 15s/step - loss: 0.8869 - mae: 0.7320 - val_loss: 1.0798 - val_mae: 0.7688 - learning_rate: 1.0000e-04
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9902 - mae: 0.7544
# Epoch 17: val_loss improved from 1.07985 to 1.07672, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 376s 15s/step - loss: 0.9881 - mae: 0.7539 - val_loss: 1.0767 - val_mae: 0.7670 - learning_rate: 1.0000e-04
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - loss: 0.9476 - mae: 0.7431
# Epoch 18: val_loss improved from 1.07672 to 1.07162, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 374s 16s/step - loss: 0.9471 - mae: 0.7430 - val_loss: 1.0716 - val_mae: 0.7653 - learning_rate: 1.0000e-04
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9607 - mae: 0.7616
# Epoch 19: val_loss improved from 1.07162 to 1.06559, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 351s 15s/step - loss: 0.9599 - mae: 0.7610 - val_loss: 1.0656 - val_mae: 0.7627 - learning_rate: 1.0000e-04
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9492 - mae: 0.7466
# Epoch 20: val_loss improved from 1.06559 to 1.05738, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 366s 15s/step - loss: 0.9483 - mae: 0.7463 - val_loss: 1.0574 - val_mae: 0.7589 - learning_rate: 1.0000e-04
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.9034 - mae: 0.7291
# Epoch 21: val_loss improved from 1.05738 to 1.04779, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 349s 15s/step - loss: 0.9038 - mae: 0.7292 - val_loss: 1.0478 - val_mae: 0.7546 - learning_rate: 1.0000e-04
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8999 - mae: 0.7297
# Epoch 22: val_loss improved from 1.04779 to 1.04076, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 392s 15s/step - loss: 0.9008 - mae: 0.7299 - val_loss: 1.0408 - val_mae: 0.7518 - learning_rate: 1.0000e-04
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9076 - mae: 0.7200
# Epoch 23: val_loss improved from 1.04076 to 1.03296, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 361s 15s/step - loss: 0.9079 - mae: 0.7204 - val_loss: 1.0330 - val_mae: 0.7482 - learning_rate: 1.0000e-04
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.8956 - mae: 0.7288
# Epoch 24: val_loss improved from 1.03296 to 1.02380, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 348s 15s/step - loss: 0.8964 - mae: 0.7288 - val_loss: 1.0238 - val_mae: 0.7434 - learning_rate: 1.0000e-04
# Epoch 25/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9651 - mae: 0.7238
# Epoch 25: val_loss improved from 1.02380 to 1.02046, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 386s 15s/step - loss: 0.9622 - mae: 0.7234 - val_loss: 1.0205 - val_mae: 0.7416 - learning_rate: 1.0000e-04
# Epoch 26/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9342 - mae: 0.7230
# Epoch 26: val_loss improved from 1.02046 to 1.00923, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 354s 15s/step - loss: 0.9326 - mae: 0.7228 - val_loss: 1.0092 - val_mae: 0.7355 - learning_rate: 1.0000e-04
# Epoch 27/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8973 - mae: 0.7275
# Epoch 27: val_loss improved from 1.00923 to 1.00311, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 357s 15s/step - loss: 0.8968 - mae: 0.7271 - val_loss: 1.0031 - val_mae: 0.7328 - learning_rate: 1.0000e-04
# Epoch 28/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8511 - mae: 0.7052
# Epoch 28: val_loss improved from 1.00311 to 0.99131, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 385s 15s/step - loss: 0.8520 - mae: 0.7053 - val_loss: 0.9913 - val_mae: 0.7269 - learning_rate: 1.0000e-04
# Epoch 29/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8559 - mae: 0.7016
# Epoch 29: val_loss improved from 0.99131 to 0.98088, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 358s 15s/step - loss: 0.8568 - mae: 0.7018 - val_loss: 0.9809 - val_mae: 0.7215 - learning_rate: 1.0000e-04
# Epoch 30/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.9260 - mae: 0.7273
# Epoch 30: val_loss improved from 0.98088 to 0.96934, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 360s 15s/step - loss: 0.9242 - mae: 0.7264 - val_loss: 0.9693 - val_mae: 0.7163 - learning_rate: 1.0000e-04
# Epoch 31/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.9615 - mae: 0.7077
# Epoch 31: val_loss improved from 0.96934 to 0.96297, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 362s 15s/step - loss: 0.9578 - mae: 0.7074 - val_loss: 0.9630 - val_mae: 0.7125 - learning_rate: 1.0000e-04
# Epoch 32/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8713 - mae: 0.7040
# Epoch 32: val_loss improved from 0.96297 to 0.95681, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 377s 16s/step - loss: 0.8708 - mae: 0.7039 - val_loss: 0.9568 - val_mae: 0.7089 - learning_rate: 1.0000e-04
# Epoch 33/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.8366 - mae: 0.6973
# Epoch 33: val_loss improved from 0.95681 to 0.94837, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 354s 15s/step - loss: 0.8368 - mae: 0.6970 - val_loss: 0.9484 - val_mae: 0.7041 - learning_rate: 1.0000e-04
# Epoch 34/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.9181 - mae: 0.6979
# Epoch 34: val_loss improved from 0.94837 to 0.93917, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 345s 14s/step - loss: 0.9149 - mae: 0.6976 - val_loss: 0.9392 - val_mae: 0.6991 - learning_rate: 1.0000e-04
# Epoch 35/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8173 - mae: 0.6864
# Epoch 35: val_loss improved from 0.93917 to 0.93657, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 360s 15s/step - loss: 0.8187 - mae: 0.6866 - val_loss: 0.9366 - val_mae: 0.6972 - learning_rate: 1.0000e-04
# Epoch 36/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.8446 - mae: 0.6988
# Epoch 36: val_loss did not improve from 0.93657
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 347s 14s/step - loss: 0.8444 - mae: 0.6984 - val_loss: 0.9387 - val_mae: 0.6982 - learning_rate: 1.0000e-04
# Epoch 37/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8880 - mae: 0.6763
# Epoch 37: val_loss improved from 0.93657 to 0.93067, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 369s 15s/step - loss: 0.8858 - mae: 0.6766 - val_loss: 0.9307 - val_mae: 0.6929 - learning_rate: 1.0000e-04
# Epoch 38/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8079 - mae: 0.6797
# Epoch 38: val_loss did not improve from 0.93067
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 351s 15s/step - loss: 0.8089 - mae: 0.6797 - val_loss: 0.9330 - val_mae: 0.6917 - learning_rate: 1.0000e-04
# Epoch 39/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8802 - mae: 0.6924
# Epoch 39: val_loss improved from 0.93067 to 0.93028, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 360s 15s/step - loss: 0.8784 - mae: 0.6919 - val_loss: 0.9303 - val_mae: 0.6919 - learning_rate: 1.0000e-04
# Epoch 40/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.7758 - mae: 0.6610
# Epoch 40: val_loss improved from 0.93028 to 0.92884, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 368s 15s/step - loss: 0.7772 - mae: 0.6614 - val_loss: 0.9288 - val_mae: 0.6903 - learning_rate: 1.0000e-04
# Epoch 41/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.7302 - mae: 0.6510
# Epoch 41: val_loss improved from 0.92884 to 0.92233, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 352s 15s/step - loss: 0.7336 - mae: 0.6517 - val_loss: 0.9223 - val_mae: 0.6861 - learning_rate: 1.0000e-04
# Epoch 42/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8126 - mae: 0.6657
# Epoch 42: val_loss improved from 0.92233 to 0.91272, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 366s 15s/step - loss: 0.8129 - mae: 0.6658 - val_loss: 0.9127 - val_mae: 0.6807 - learning_rate: 1.0000e-04
# Epoch 43/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - loss: 0.8104 - mae: 0.6778
# Epoch 43: val_loss improved from 0.91272 to 0.91182, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 343s 14s/step - loss: 0.8109 - mae: 0.6778 - val_loss: 0.9118 - val_mae: 0.6794 - learning_rate: 1.0000e-04
# Epoch 44/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8581 - mae: 0.6664
# Epoch 44: val_loss improved from 0.91182 to 0.91178, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 370s 15s/step - loss: 0.8560 - mae: 0.6665 - val_loss: 0.9118 - val_mae: 0.6778 - learning_rate: 1.0000e-04
# Epoch 45/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8344 - mae: 0.6783
# Epoch 45: val_loss improved from 0.91178 to 0.90444, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 359s 15s/step - loss: 0.8338 - mae: 0.6780 - val_loss: 0.9044 - val_mae: 0.6739 - learning_rate: 1.0000e-04
# Epoch 46/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.7816 - mae: 0.6761
# Epoch 46: val_loss improved from 0.90444 to 0.90323, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 360s 15s/step - loss: 0.7840 - mae: 0.6764 - val_loss: 0.9032 - val_mae: 0.6727 - learning_rate: 1.0000e-04
# Epoch 47/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.7604 - mae: 0.6597
# Epoch 47: val_loss did not improve from 0.90323
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 354s 15s/step - loss: 0.7625 - mae: 0.6601 - val_loss: 0.9056 - val_mae: 0.6728 - learning_rate: 1.0000e-04
# Epoch 48/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8056 - mae: 0.6587
# Epoch 48: val_loss improved from 0.90323 to 0.90256, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 349s 15s/step - loss: 0.8053 - mae: 0.6587 - val_loss: 0.9026 - val_mae: 0.6713 - learning_rate: 1.0000e-04
# Epoch 49/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.8181 - mae: 0.6666
# Epoch 49: val_loss improved from 0.90256 to 0.89400, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 368s 15s/step - loss: 0.8175 - mae: 0.6664 - val_loss: 0.8940 - val_mae: 0.6685 - learning_rate: 1.0000e-04
# Epoch 50/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - loss: 0.7593 - mae: 0.6551
# Epoch 50: val_loss improved from 0.89400 to 0.89087, saving model to /content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 365s 15s/step - loss: 0.7612 - mae: 0.6557 - val_loss: 0.8909 - val_mae: 0.6659 - learning_rate: 1.0000e-04

# %% [markdown]
# ### Plot Learning Curves

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Learning Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,5))
plt.plot(history.history["mae"], label="Training MAE")
plt.plot(history.history["val_mae"], label="Validation MAE")
plt.title("Training vs Validation MAE")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate the Model on Validation Data

# %%
val_loss, val_mae = model.evaluate(val_generator)
print("Validation Loss:", val_loss)
print("Validation MAE :", val_mae)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 68s 11s/step - loss: 0.8426 - mae: 0.6530
# Validation Loss: 0.890870988368988
# Validation MAE : 0.6659196019172668

# %% [markdown]
# ### Predict on Validation Set

# %%
y_true = val_split_df[target_cols].values
y_pred = model.predict(val_generator)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 68s 10s/step

# %% [markdown]
# ### Compute Regression Metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_true, y_pred, multioutput="raw_values")
rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="raw_values"))
r2 = [r2_score(y_true[:, i], y_pred[:, i]) for i in range(y_true.shape[1])]

metrics_df = pd.DataFrame({
    "Target": target_cols,
    "MAE": mae,
    "RMSE": rmse,
    "R2": r2
})

display(metrics_df.sort_values("MAE"))
# Out:
#                  Target       MAE      RMSE        R2
# 3          Medium_Count  0.321034  1.348300  0.022529
# 12            Average_L  0.554964  0.780066  0.436675
# 8           Green_Count  0.562297  1.069045  0.106674
# 1          Broken_Count  0.570599  0.961709  0.094216
# 0                 Count  0.593749  0.862485  0.213521
# 5          Chalky_Count  0.641628  0.764414  0.314028
# 6             Red_Count  0.658217  0.865752  0.100865
# 14            Average_b  0.681468  0.767188  0.413107
# 7          Yellow_Count  0.717128  1.078401  0.005665
# 10     WK_Width_Average  0.747185  0.891250  0.210200
# 4           Black_Count  0.747973  0.839458  0.328467
# 11  WK_LW_Ratio_Average  0.763102  1.057847  0.012719
# 13            Average_a  0.774760  0.855410  0.315958
# 9     WK_Length_Average  0.799415  0.892221  0.230257
# 2            Long_Count  0.855273  0.945411  0.144545

# %% [markdown]
# ### Inverse Transform Predictions Back to Original Scale

# %%
# Load scaler if needed
target_scaler = joblib.load("/content/drive/MyDrive/Mission Capstone/Dataset/target_scaler.pkl")

y_true_original = target_scaler.inverse_transform(y_true)
y_pred_original = target_scaler.inverse_transform(y_pred)

results_df = pd.DataFrame(y_pred_original, columns=[f"Pred_{c}" for c in target_cols])
true_df = pd.DataFrame(y_true_original, columns=[f"True_{c}" for c in target_cols])

comparison_df = pd.concat([true_df.reset_index(drop=True), results_df.reset_index(drop=True)], axis=1)
display(comparison_df.head())
# Out:
#    True_Count  True_Broken_Count  True_Long_Count  True_Medium_Count  \
# 0      2211.0             1164.0            766.0                4.0
# 1      1669.0              500.0           1011.0                0.0
# 2      1339.0              123.0           1117.0                0.0
# 3      1283.0              217.0            901.0                0.0
# 4      1275.0              235.0            870.0                0.0
#
#    True_Black_Count  True_Chalky_Count  True_Red_Count  True_Yellow_Count  \
# 0             328.0              841.0             3.0               24.0
# 1              67.0              428.0             0.0               13.0
# 2              41.0              383.0             0.0                9.0
# 3             190.0              860.0            19.0              214.0
# 4             123.0             1009.0            19.0              124.0
#
#    True_Green_Count  True_WK_Length_Average  ...  Pred_Chalky_Count  \
# 0             414.0                    6.41  ...         485.572266
# 1             759.0                    6.48  ...         542.124573
# 2             108.0                    6.69  ...         432.464203
# 3               0.0                    7.04  ...         374.269012
# 4               0.0                    7.05  ...         366.074188
#
#    Pred_Red_Count  Pred_Yellow_Count  Pred_Green_Count  \
# 0       18.064342          68.522087         75.329720
# 1       17.176056          67.825325         81.950424
# 2       18.939041          70.450378         65.919312
# 3       20.199373          74.649185         52.012226
# 4       20.353876          75.208855         50.620136
#
#    Pred_WK_Length_Average  Pred_WK_Width_Average  Pred_WK_LW_Ratio_Average  \
# 0                7.622652               2.555446                  3.067032
# 1                7.522322               2.527397                  3.043719
# 2                7.737689               2.597315                  3.095684
# 3                7.883286               2.648584                  3.122798
# 4                7.906286               2.655833                  3.126322
#
#    Pred_Average_L  Pred_Average_a  Pred_Average_b
# 0       64.127853        2.710475       15.222020
# 1       65.239403        2.058315       13.513187
# 2       63.124329        3.421053       16.945303
# 3       62.166218        4.207887       19.391993
# 4       62.013168        4.320104       19.721630
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Visualize True vs Predicted for Important Targets

# %%
important_targets = ["Count", "Broken_Count", "WK_Length_Average", "WK_LW_Ratio_Average"]

for col in important_targets:
    if col in target_cols:
        idx = target_cols.index(col)

        plt.figure(figsize=(6,6))
        plt.scatter(y_true_original[:, idx], y_pred_original[:, idx], alpha=0.6)
        plt.xlabel(f"True {col}")
        plt.ylabel(f"Predicted {col}")
        plt.title(f"True vs Predicted: {col}")
        plt.plot(
            [y_true_original[:, idx].min(), y_true_original[:, idx].max()],
            [y_true_original[:, idx].min(), y_true_original[:, idx].max()],
            'r--'
        )
        plt.show()

# %% [markdown]
# ### Save Final Model fro backup

# %%
model.save("/content/drive/MyDrive/Mission Capstone/Dataset/final_rice_model.h5")
print("Final model saved.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Final model saved.

# %% [markdown]
# ### Predict on One Image

# %%
from tensorflow.keras.preprocessing import image

def predict_one_image(img_path, model, scaler, target_cols):
    img = image.load_img(img_path, target_size=(224, 224))
    img = image.img_to_array(img) / 255.0
    img = np.expand_dims(img, axis=0)

    pred_scaled = model.predict(img)
    pred_original = scaler.inverse_transform(pred_scaled)[0]

    return dict(zip(target_cols, pred_original))

sample_image = os.path.join(LOCAL_IMAGE_PATH, train_df["filename"].iloc[0])
sample_prediction = predict_one_image(sample_image, model, target_scaler, target_cols)

sample_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# {'Count': np.float32(1278.3993),
#  'Broken_Count': np.float32(383.83603),
#  'Long_Count': np.float32(522.06635),
#  'Medium_Count': np.float32(0.92306215),
#  'Black_Count': np.float32(735.83856),
#  'Chalky_Count': np.float32(333.0909),
#  'Red_Count': np.float32(21.068644),
#  'Yellow_Count': np.float32(77.547775),
#  'Green_Count': np.float32(43.863514),
#  'WK_Length_Average': np.float32(8.000536),
#  'WK_Width_Average': np.float32(2.6872182),
#  'WK_LW_Ratio_Average': np.float32(3.1393864),
#  'Average_L': np.float32(61.37565),
#  'Average_a': np.float32(4.784925),
#  'Average_b': np.float32(21.156715)}

# %% [markdown]
# ### Convert Raw Outputs into Rice Quality Interpretation

# %%
def interpret_rice_quality(pred):
    count = max(pred.get("Count", 1), 1)
    broken = pred.get("Broken_Count", 0)
    long_count = pred.get("Long_Count", 0)
    medium_count = pred.get("Medium_Count", 0)
    chalky = pred.get("Chalky_Count", 0)
    lw_ratio = pred.get("WK_LW_Ratio_Average", 0)

    broken_pct = (broken / count) * 100
    long_pct = (long_count / count) * 100
    medium_pct = (medium_count / count) * 100
    chalky_pct = (chalky / count) * 100

    # Milling grade
    if broken_pct < 5:
        milling_grade = "Premium"
    elif broken_pct < 10:
        milling_grade = "Grade 1"
    elif broken_pct < 15:
        milling_grade = "Grade 2"
    elif broken_pct < 20:
        milling_grade = "Grade 3"
    else:
        milling_grade = "Below Grade"

    # Grain shape
    if lw_ratio < 2.1:
        grain_shape = "Bold"
    elif 2.1 <= lw_ratio <= 2.9:
        grain_shape = "Medium"
    else:
        grain_shape = "Slender"

    # Grain length class
    if long_pct > 90:
        grain_length_class = "Long Grain"
    elif medium_pct > 90:
        grain_length_class = "Medium Grain"
    else:
        grain_length_class = "Mixed Grain"

    # Chalkiness
    chalkiness_status = "Chalky" if chalky_pct > 20 else "Not Chalky"

    return {
        "broken_pct": broken_pct,
        "long_pct": long_pct,
        "medium_pct": medium_pct,
        "chalky_pct": chalky_pct,
        "milling_grade": milling_grade,
        "grain_shape": grain_shape,
        "grain_length_class": grain_length_class,
        "chalkiness_status": chalkiness_status
    }

interpreted_result = interpret_rice_quality(sample_prediction)
interpreted_result
# Out:
# {'broken_pct': np.float32(30.024736),
#  'long_pct': np.float32(40.8375),
#  'medium_pct': np.float32(0.07220452),
#  'chalky_pct': np.float32(26.055313),
#  'milling_grade': 'Below Grade',
#  'grain_shape': 'Slender',
#  'grain_length_class': 'Mixed Grain',
#  'chalkiness_status': 'Chalky'}

# %% [markdown]
# ### Final Output for AminoRice

# %%
final_output = {
    "raw_model_outputs": sample_prediction,
    "interpreted_quality": interpreted_result
}

final_output
# Out:
# {'raw_model_outputs': {'Count': np.float32(1278.3993),
#   'Broken_Count': np.float32(383.83603),
#   'Long_Count': np.float32(522.06635),
#   'Medium_Count': np.float32(0.92306215),
#   'Black_Count': np.float32(735.83856),
#   'Chalky_Count': np.float32(333.0909),
#   'Red_Count': np.float32(21.068644),
#   'Yellow_Count': np.float32(77.547775),
#   'Green_Count': np.float32(43.863514),
#   'WK_Length_Average': np.float32(8.000536),
#   'WK_Width_Average': np.float32(2.6872182),
#   'WK_LW_Ratio_Average': np.float32(3.1393864),
#   'Average_L': np.float32(61.37565),
#   'Average_a': np.float32(4.784925),
#   'Average_b': np.float32(21.156715)},
#  'interpreted_quality': {'broken_pct': np.float32(30.024736),
#   'long_pct': np.float32(40.8375),
#   'medium_pct': np.float32(0.07220452),
#   'chalky_pct': np.float32(26.055313),
#   'milling_grade': 'Below Grade',
#   'grain_shape': 'Slender',
#   'grain_length_class': 'Mixed Grain',
#   'chalkiness_status': 'Chalky'}}

# %% [markdown]
# ## Make Predictions
# ### Load the Best Model

# %%
import os
import numpy as np
import pandas as pd
import joblib
from PIL import Image
import tensorflow as tf

# %%
BEST_MODEL_PATH = "/content/drive/MyDrive/Mission Capstone/Dataset/best_rice_model_efficientnetb0.h5"
SCALER_PATH = "/content/drive/MyDrive/Mission Capstone/Dataset/target_scaler.pkl"

model = tf.keras.models.load_model(BEST_MODEL_PATH, compile=False)
target_scaler = joblib.load(SCALER_PATH)

print("Best model loaded successfully.")
print("Scaler loaded successfully.")
# Out:
# Best model loaded successfully.
# Scaler loaded successfully.

# %% [markdown]
# ### Define the Exact Target Columns

# %%
target_cols = [
    "Count",
    "Broken_Count",
    "Long_Count",
    "Medium_Count",
    "Black_Count",
    "Chalky_Count",
    "Red_Count",
    "Yellow_Count",
    "Green_Count",
    "WK_Length_Average",
    "WK_Width_Average",
    "WK_LW_Ratio_Average",
    "Average_L",
    "Average_a",
    "Average_b"
]

# %% [markdown]
# ### Build Image Preprocessing Function

# %%
IMG_SIZE = (224, 224)

def preprocess_image(image_path):
    img = Image.open(image_path).convert("RGB")
    img = img.resize(IMG_SIZE)
    img = np.array(img).astype("float32") / 255.0
    img = np.expand_dims(img, axis=0)
    return img

# %% [markdown]
# ### Build Rule-Based Interpretation Function

# %%
def interpret_rice_quality(pred):
    count = max(float(pred.get("Count", 1)), 1.0)
    broken = max(float(pred.get("Broken_Count", 0)), 0.0)
    long_count = max(float(pred.get("Long_Count", 0)), 0.0)
    medium_count = max(float(pred.get("Medium_Count", 0)), 0.0)
    black = max(float(pred.get("Black_Count", 0)), 0.0)
    chalky = max(float(pred.get("Chalky_Count", 0)), 0.0)
    red = max(float(pred.get("Red_Count", 0)), 0.0)
    yellow = max(float(pred.get("Yellow_Count", 0)), 0.0)
    green = max(float(pred.get("Green_Count", 0)), 0.0)
    lw_ratio = float(pred.get("WK_LW_Ratio_Average", 0))

    broken_pct = (broken / count) * 100
    long_pct = (long_count / count) * 100
    medium_pct = (medium_count / count) * 100
    black_pct = (black / count) * 100
    chalky_pct = (chalky / count) * 100
    red_pct = (red / count) * 100
    yellow_pct = (yellow / count) * 100
    green_pct = (green / count) * 100

    # Milling grade
    if broken_pct < 5:
        milling_grade = "Premium"
    elif broken_pct < 10:
        milling_grade = "Grade 1"
    elif broken_pct < 15:
        milling_grade = "Grade 2"
    elif broken_pct < 20:
        milling_grade = "Grade 3"
    else:
        milling_grade = "Below Grade"

    # Grain shape
    if lw_ratio < 2.1:
        grain_shape = "Bold"
    elif 2.1 <= lw_ratio <= 2.9:
        grain_shape = "Medium"
    else:
        grain_shape = "Slender"

    # Grain length class
    if long_pct > 90:
        grain_length_class = "Long Grain"
    elif medium_pct > 90:
        grain_length_class = "Medium Grain"
    else:
        grain_length_class = "Mixed Grain"

    # Chalkiness
    chalkiness_status = "Chalky" if chalky_pct > 20 else "Not Chalky"

    # Simple defect alerts
    alerts = []
    if black_pct > 1:
        alerts.append("Black grains detected")
    if red_pct > 1:
        alerts.append("Red grains detected")
    if yellow_pct > 1:
        alerts.append("Yellow grains detected")
    if green_pct > 1:
        alerts.append("Green grains detected")
    if chalky_pct > 20:
        alerts.append("High chalkiness detected")
    if broken_pct >= 20:
        alerts.append("High broken grain percentage")

    return {
        "broken_percentage": round(broken_pct, 2),
        "long_percentage": round(long_pct, 2),
        "medium_percentage": round(medium_pct, 2),
        "chalky_percentage": round(chalky_pct, 2),
        "black_percentage": round(black_pct, 2),
        "red_percentage": round(red_pct, 2),
        "yellow_percentage": round(yellow_pct, 2),
        "green_percentage": round(green_pct, 2),
        "milling_grade": milling_grade,
        "grain_shape": grain_shape,
        "grain_length_class": grain_length_class,
        "chalkiness_status": chalkiness_status,
        "alerts": alerts
    }

# %% [markdown]
# ### Build the Single AminoRice Prediction Function

# %%
def amino_rice_predict(image_path, model, scaler, target_cols):
    # preprocess
    img = preprocess_image(image_path)

    # predict scaled outputs
    pred_scaled = model.predict(img, verbose=0)

    # inverse transform back to original units
    pred_original = scaler.inverse_transform(pred_scaled)[0]

    # raw outputs dictionary
    raw_outputs = dict(zip(target_cols, pred_original))

    # clean negative count-like values
    count_like_cols = [
        "Count", "Broken_Count", "Long_Count", "Medium_Count",
        "Black_Count", "Chalky_Count", "Red_Count", "Yellow_Count", "Green_Count"
    ]

    for col in count_like_cols:
        if col in raw_outputs:
            raw_outputs[col] = max(0.0, float(raw_outputs[col]))

    # round outputs nicely
    cleaned_outputs = {}
    for k, v in raw_outputs.items():
        cleaned_outputs[k] = round(float(v), 3)

    # interpret
    interpreted = interpret_rice_quality(cleaned_outputs)

    return {
        "image_path": image_path,
        "raw_model_outputs": cleaned_outputs,
        "interpreted_quality": interpreted
    }

# %% [markdown]
# ### Test on One Image

# %%
sample_image = "/content/images/ID_2BCAB9.png"
result = amino_rice_predict(sample_image, model, target_scaler, target_cols)
result
# Out:
# {'image_path': '/content/images/ID_2BCAB9.png',
#  'raw_model_outputs': {'Count': 1147.77,
#   'Broken_Count': 304.108,
#   'Long_Count': 443.429,
#   'Medium_Count': 0.481,
#   'Black_Count': 947.286,
#   'Chalky_Count': 131.498,
#   'Red_Count': 24.25,
#   'Yellow_Count': 88.062,
#   'Green_Count': 0.0,
#   'WK_Length_Average': 8.467,
#   'WK_Width_Average': 2.832,
#   'WK_LW_Ratio_Average': 3.222,
#   'Average_L': 58.055,
#   'Average_a': 7.351,
#   'Average_b': 28.559},
#  'interpreted_quality': {'broken_percentage': 26.5,
#   'long_percentage': 38.63,
#   'medium_percentage': 0.04,
#   'chalky_percentage': 11.46,
#   'black_percentage': 82.53,
#   'red_percentage': 2.11,
#   'yellow_percentage': 7.67,
#   'green_percentage': 0.0,
#   'milling_grade': 'Below Grade',
#   'grain_shape': 'Slender',
#   'grain_length_class': 'Mixed Grain',
#   'chalkiness_status': 'Not Chalky',
#   'alerts': ['Black grains detected',
#    'Red grains detected',
#    'Yellow grains detected',
#    'High broken grain percentage']}}

# %% [markdown]
# ### Pretty Print the Result

# %%
import json
print(json.dumps(result, indent=4))
# Out:
# {
#     "image_path": "/content/images/ID_2BCAB9.png",
#     "raw_model_outputs": {
#         "Count": 1147.77,
#         "Broken_Count": 304.108,
#         "Long_Count": 443.429,
#         "Medium_Count": 0.481,
#         "Black_Count": 947.286,
#         "Chalky_Count": 131.498,
#         "Red_Count": 24.25,
#         "Yellow_Count": 88.062,
#         "Green_Count": 0.0,
#         "WK_Length_Average": 8.467,
#         "WK_Width_Average": 2.832,
#         "WK_LW_Ratio_Average": 3.222,
#         "Average_L": 58.055,
#         "Average_a": 7.351,
#         "Average_b": 28.559
#     },
#     "interpreted_quality": {
#         "broken_percentage": 26.5,
#         "long_percentage": 38.63,
#         "medium_percentage": 0.04,
#         "chalky_percentage": 11.46,
#         "black_percentage": 82.53,
#         "red_percentage": 2.11,
#         "yellow_percentage": 7.67,
#         "green_percentage": 0.0,
#         "milling_grade": "Below Grade",
#         "grain_shape": "Slender",
#         "grain_length_class": "Mixed Grain",
#         "chalkiness_status": "Not Chalky",
#         "alerts": [
#             "Black grains detected",
#             "Red grains detected",
#             "Yellow grains detected",
#             "High broken grain percentage"
#         ]
#     }
# }

# %% [markdown]
# ### Show a Simple User-Facing Summary

# %%
def display_amino_summary(result):
    q = result["interpreted_quality"]
    r = result["raw_model_outputs"]

    print("=== AminoRice Quality Report ===")
    print(f"Milling Grade       : {q['milling_grade']}")
    print(f"Grain Shape         : {q['grain_shape']}")
    print(f"Grain Length Class  : {q['grain_length_class']}")
    print(f"Chalkiness Status   : {q['chalkiness_status']}")
    print(f"Broken %            : {q['broken_percentage']}%")
    print(f"Chalky %            : {q['chalky_percentage']}%")
    print(f"L/W Ratio           : {r['WK_LW_Ratio_Average']}")
    print(f"Average Length      : {r['WK_Length_Average']}")
    print(f"Average Width       : {r['WK_Width_Average']}")

    if q["alerts"]:
        print("Alerts              :")
        for alert in q["alerts"]:
            print(f" - {alert}")
    else:
        print("Alerts              : None")

# %%
display_amino_summary(result)
# Out:
# === AminoRice Quality Report ===
# Milling Grade       : Below Grade
# Grain Shape         : Slender
# Grain Length Class  : Mixed Grain
# Chalkiness Status   : Not Chalky
# Broken %            : 26.5%
# Chalky %            : 11.46%
# L/W Ratio           : 3.222
# Average Length      : 8.467
# Average Width       : 2.832
# Alerts              :
#  - Black grains detected
#  - Red grains detected
#  - Yellow grains detected
#  - High broken grain percentage

# %%
uploaded_image_path = "        "
result = amino_rice_predict(uploaded_image_path, model, target_scaler, target_cols)
return result
